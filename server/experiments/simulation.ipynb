# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100)
# Out:
# Adversary: Start SCAN_HOST at 0.0s.
# MTD: ServiceDiversity triggered 0.0s
# MTD: ServiceDiversity deployed in the network at 0.0s.
# Adversary: Processed SCAN_HOST at 5.0s.
# Adversary: Start ENUM_HOST at 5.0s.
# Adversary: Processed ENUM_HOST at 10.0s.
# Adversary: Start SCAN_PORT at 10.0s.
# Adversary: Processed SCAN_PORT at 35.0s.
# Adversary: Start EXPLOIT_VULN 84d3ecec-f01d-4426-aee1-bae56a59b58a on host 0 at 35.0s.
# Adversary: Processed EXPLOIT_VULN 84d3ecec-f01d-4426-aee1-bae56a59b58a on host 0 at 35.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 60f763d5-5d09-4419-8c4c-22e34d1fb73b on host 0 at 35.8s.
# Adversary: Processed EXPLOIT_VULN 60f763d5-5d09-4419-8c4c-22e34d1fb73b on host 0 at 37.8s.
# Adversary: Start EXPLOIT_VULN 0e8445f1-0627-4196-a7a6-d4010b9de7fc on host 0 at 37.8s.
# Adversary: Processed EXPLOIT_VULN 0e8445f1-0627-4196-a7a6-d4010b9de7fc on host 0 at 56.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 41f5c9a0-6063-47ce-8713-69d5876dcb95 on host 0 at 56.0s.
# MTD: ServiceDiversity finished in 70.8s at 70.8s.
# MTD: Interrupted EXPLOIT_VULN at 70.8s!
# Adversary: Restarting with SCAN_PORT at 91.0s!
# Adversary: Start SCAN_PORT at 91.0s.
# Adversary: Processed SCAN_PORT at 116.0s.
# Adversary: Start EXPLOIT_VULN e70e0d8a-29e8-44fd-9f91-b100a64cb77f on host 0 at 116.0s.
# Adversary: Processed EXPLOIT_VULN e70e0d8a-29e8-44fd-9f91-b100a64cb77f on host 0 at 116.6s.
# Adversary: Start EXPLOIT_VULN 700139e4-4dee-46d9-b5c0-08c5fb60ce11 on host 0 at 116.6s.
# Adversary: Processed EXPLOIT_VULN 700139e4-4dee-46d9-b5c0-08c5fb60ce11 on host 0 at 119.0s.
# Adversary: Start EXPLOIT_VULN cbbce3b1-c6b3-4f16-a0f8-97154af1c634 on host 0 at 119.0s.
# Adversary: Processed EXPLOIT_VULN cbbce3b1-c6b3-4f16-a0f8-97154af1c634 on host 0 at 126.3s.
# Adversary: Start EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 126.3s.
# Adversary: Processed EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 134.3s.
# Adversary: Start EXPLOIT_VULN 7b91a054-ce85-4f2c-b6d8-a51c06646409 on host 0 at 134.3s.
# Adversary: Processed EXPLOIT_VULN 7b91a054-ce85-4f2c-b6d8-a51c06646409 on host 0 at 136.0s.
# Adversary: Start EXPLOIT_VULN eefa5fc0-ca8c-4a1a-ba39-fd3db0046db4 on host 0 at 136.0s.
# Adversary: Processed EXPLOIT_VULN eefa5fc0-ca8c-4a1a-ba39-fd3db0046db4 on host 0 at 142.3s.
# Adversary: Start EXPLOIT_VULN 78f8a6d0-94fb-44af-8db3-692981c3b6b4 on host 0 at 142.3s.
# Adversary: Processed EXPLOIT_VULN 78f8a6d0-94fb-44af-8db3-692981c3b6b4 on host 0 at 150.8s.
# Adversary: Start EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 150.8s.
# Adversary: Processed EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 159.6s.
# Adversary: Start EXPLOIT_VULN 48c4c7cb-9798-41c1-8d56-9be1a849f4ad on host 0 at 159.6s.
# Adversary: Processed EXPLOIT_VULN 48c4c7cb-9798-41c1-8d56-9be1a849f4ad on host 0 at 163.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a7acb6c9-4cdf-4e8c-b057-2e93b988aa88 on host 0 at 163.1s.
# Adversary: Processed EXPLOIT_VULN a7acb6c9-4cdf-4e8c-b057-2e93b988aa88 on host 0 at 163.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2eabc439-8fed-412a-a59c-3db9010b8963 on host 0 at 163.9s.
# Adversary: Processed EXPLOIT_VULN 2eabc439-8fed-412a-a59c-3db9010b8963 on host 0 at 167.1s.
# Adversary: Start EXPLOIT_VULN e99f4f9d-cfdc-4eca-8c9d-3ba7572c43c8 on host 0 at 167.1s.
# Adversary: Processed EXPLOIT_VULN e99f4f9d-cfdc-4eca-8c9d-3ba7572c43c8 on host 0 at 172.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b0762461-dfbe-43be-b66b-7d552f2e9e7c on host 0 at 172.5s.
# Adversary: Processed EXPLOIT_VULN b0762461-dfbe-43be-b66b-7d552f2e9e7c on host 0 at 180.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c7787d28-c5ca-406d-b1a0-47d587656dee on host 0 at 180.4s.
# Adversary: Processed EXPLOIT_VULN c7787d28-c5ca-406d-b1a0-47d587656dee on host 0 at 198.6s.
# Adversary: Start EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 198.6s.
# MTD: IPShuffle triggered 200.0s
# MTD: IPShuffle deployed in the network at 200.0s.
# Adversary: Processed EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 205.2s.
# Adversary: Start EXPLOIT_VULN 7b88942d-97a3-4f81-9988-20dd52421fb7 on host 0 at 205.2s.
# Adversary: Processed EXPLOIT_VULN 7b88942d-97a3-4f81-9988-20dd52421fb7 on host 0 at 210.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a6a26e8f-0762-4ad2-a32b-e62dc4c60e65 on host 0 at 210.2s.
# Adversary: Processed EXPLOIT_VULN a6a26e8f-0762-4ad2-a32b-e62dc4c60e65 on host 0 at 213.8s.
# Adversary: Start EXPLOIT_VULN 762b01b9-57fd-4546-b5ff-d278b7dba10f on host 0 at 213.8s.
# Adversary: Processed EXPLOIT_VULN 762b01b9-57fd-4546-b5ff-d278b7dba10f on host 0 at 219.7s.
# Adversary: Start EXPLOIT_VULN df12cdd6-0174-4382-a53e-8aa13de69836 on host 0 at 219.7s.
# Adversary: Processed EXPLOIT_VULN df12cdd6-0174-4382-a53e-8aa13de69836 on host 0 at 222.9s.
# Adversary: Start EXPLOIT_VULN 5a98666d-3cdf-4558-a8e0-5b691a904701 on host 0 at 222.9s.
# Adversary: Processed EXPLOIT_VULN 5a98666d-3cdf-4558-a8e0-5b691a904701 on host 0 at 231.1s.
# Adversary: Start EXPLOIT_VULN 595e647e-7422-4465-b80d-45c94ea2d871 on host 0 at 231.1s.
# Adversary: Processed EXPLOIT_VULN 595e647e-7422-4465-b80d-45c94ea2d871 on host 0 at 240.8s.
# Adversary: Start EXPLOIT_VULN 4fd783b0-3390-4aea-b29c-1444698a28db on host 0 at 240.8s.
# Adversary: Processed EXPLOIT_VULN 4fd783b0-3390-4aea-b29c-1444698a28db on host 0 at 243.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 41f5c9a0-6063-47ce-8713-69d5876dcb95 on host 0 at 243.5s.
# Adversary: Processed EXPLOIT_VULN 41f5c9a0-6063-47ce-8713-69d5876dcb95 on host 0 at 264.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e85589a9-1130-4409-a602-129606b04b21 on host 0 at 264.7s.
# Adversary: Processed EXPLOIT_VULN e85589a9-1130-4409-a602-129606b04b21 on host 0 at 271.8s.
# Adversary: Start EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 271.8s.
# Adversary: Processed EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 281.0s.
# Adversary: Start EXPLOIT_VULN dbf36819-de2e-4820-9893-89074e374c09 on host 0 at 281.0s.
# Adversary: Processed EXPLOIT_VULN dbf36819-de2e-4820-9893-89074e374c09 on host 0 at 283.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 85272a39-30ca-4171-affc-df8a5a55c8d1 on host 0 at 283.5s.
# Adversary: Processed EXPLOIT_VULN 85272a39-30ca-4171-affc-df8a5a55c8d1 on host 0 at 289.5s.
# Adversary: Start EXPLOIT_VULN 28133f46-e2a4-4bfd-a886-86c9ee373e04 on host 0 at 289.5s.
# Adversary: Processed EXPLOIT_VULN 28133f46-e2a4-4bfd-a886-86c9ee373e04 on host 0 at 309.8s.
# Adversary: Start EXPLOIT_VULN ec49ba6a-be0c-4676-bc03-6a4f033e33fe on host 0 at 309.8s.
# MTD: IPShuffle finished in 110.1s at 310.1s.
# MTD: Interrupted EXPLOIT_VULN at 310.1s!
# Adversary: Restarting with SCAN_HOST at 330.4s!
# Adversary: Start SCAN_HOST at 330.4s.
# Adversary: Processed SCAN_HOST at 335.4s.
# Adversary: Start ENUM_HOST at 335.4s.
# Adversary: Processed ENUM_HOST at 340.4s.
# Adversary: Start SCAN_PORT at 340.4s.
# Adversary: Processed SCAN_PORT at 365.4s.
# Adversary: Start EXPLOIT_VULN 2eabc439-8fed-412a-a59c-3db9010b8963 on host 0 at 365.4s.
# Adversary: Processed EXPLOIT_VULN 2eabc439-8fed-412a-a59c-3db9010b8963 on host 0 at 368.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 368.7s.
# Adversary: Processed EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 375.1s.
# Adversary: Start EXPLOIT_VULN ded584b0-0147-411c-9894-620dcb309bae on host 0 at 375.1s.
# Adversary: Processed EXPLOIT_VULN ded584b0-0147-411c-9894-620dcb309bae on host 0 at 378.6s.
# Adversary: Start EXPLOIT_VULN cbbce3b1-c6b3-4f16-a0f8-97154af1c634 on host 0 at 378.6s.
# Adversary: Processed EXPLOIT_VULN cbbce3b1-c6b3-4f16-a0f8-97154af1c634 on host 0 at 386.0s.
# Adversary: Start EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 386.0s.
# Adversary: Processed EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 393.9s.
# Adversary: Start EXPLOIT_VULN db8acfa0-d088-4740-bec2-e4c6c984bfa2 on host 0 at 393.9s.
# MTD: CompleteTopologyShuffle triggered 400.0s
# MTD: CompleteTopologyShuffle deployed in the network at 400.0s.
# Adversary: Processed EXPLOIT_VULN db8acfa0-d088-4740-bec2-e4c6c984bfa2 on host 0 at 400.3s.
# Adversary: Start EXPLOIT_VULN e85589a9-1130-4409-a602-129606b04b21 on host 0 at 400.3s.
# Adversary: Processed EXPLOIT_VULN e85589a9-1130-4409-a602-129606b04b21 on host 0 at 407.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 407.3s.
# Adversary: Processed EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 415.6s.
# Adversary: Start EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 415.6s.
# Adversary: Processed EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 425.0s.
# Adversary: Start EXPLOIT_VULN c7787d28-c5ca-406d-b1a0-47d587656dee on host 0 at 425.0s.
# Adversary: Processed EXPLOIT_VULN c7787d28-c5ca-406d-b1a0-47d587656dee on host 0 at 443.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 64b5346e-8732-4ec7-8331-e94cc72117d9 on host 0 at 443.6s.
# Adversary: Processed EXPLOIT_VULN 64b5346e-8732-4ec7-8331-e94cc72117d9 on host 0 at 447.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5e9cc002-afbb-427a-9973-d6418e3a88a1 on host 0 at 447.1s.
# Adversary: Processed EXPLOIT_VULN 5e9cc002-afbb-427a-9973-d6418e3a88a1 on host 0 at 456.4s.
# Adversary: Start EXPLOIT_VULN 1d60854a-4eb9-4bdb-93e0-42214646d3d6 on host 0 at 456.4s.
# Adversary: Processed EXPLOIT_VULN 1d60854a-4eb9-4bdb-93e0-42214646d3d6 on host 0 at 464.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 0 at 464.0s.
# Adversary: Processed EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 0 at 486.2s.
# Adversary: Start EXPLOIT_VULN ec49ba6a-be0c-4676-bc03-6a4f033e33fe on host 0 at 486.2s.
# Adversary: Processed EXPLOIT_VULN ec49ba6a-be0c-4676-bc03-6a4f033e33fe on host 0 at 506.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 96f60740-cab1-4acb-b5c9-f35df656a32e on host 0 at 506.0s.
# MTD: CompleteTopologyShuffle finished in 120.1s at 520.1s.
# MTD: Interrupted EXPLOIT_VULN at 520.1s!
# Adversary: Restarting with SCAN_HOST at 540.7s!
# Adversary: Start SCAN_HOST at 540.7s.
# Adversary: Processed SCAN_HOST at 545.7s.
# Adversary: Start ENUM_HOST at 545.7s.
# Adversary: Processed ENUM_HOST at 550.7s.
# Adversary: Start SCAN_PORT at 550.7s.
# Adversary: Processed SCAN_PORT at 575.7s.
# Adversary: Start EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 575.7s.
# Adversary: Processed EXPLOIT_VULN f1a7a574-fc07-4742-b2b1-9d8c4e959562 on host 0 at 582.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 582.2s.
# Adversary: Processed EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 590.3s.
# Adversary: Start EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 590.3s.
# Adversary: Processed EXPLOIT_VULN 8ceb475c-938c-47fe-8104-4e4553d271b8 on host 0 at 599.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 599.0s.
# MTD: ServiceDiversity triggered 600.3s
# MTD: ServiceDiversity deployed in the network at 600.3s.
# Adversary: Processed EXPLOIT_VULN 252bb3be-bea1-41e4-b55f-f9ecad7892c4 on host 0 at 608.3s.
# Adversary: Start EXPLOIT_VULN 96f60740-cab1-4acb-b5c9-f35df656a32e on host 0 at 608.3s.
# Adversary: Processed EXPLOIT_VULN 96f60740-cab1-4acb-b5c9-f35df656a32e on host 0 at 625.7s.
# Adversary: Start EXPLOIT_VULN 85272a39-30ca-4171-affc-df8a5a55c8d1 on host 0 at 625.7s.
# Adversary: Processed EXPLOIT_VULN 85272a39-30ca-4171-affc-df8a5a55c8d1 on host 0 at 632.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 28133f46-e2a4-4bfd-a886-86c9ee373e04 on host 0 at 632.3s.
# Adversary: Processed EXPLOIT_VULN 28133f46-e2a4-4bfd-a886-86c9ee373e04 on host 0 at 652.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 0 at 652.6s.
# MTD: ServiceDiversity finished in 70.2s at 670.5s.
# MTD: Interrupted EXPLOIT_VULN at 670.5s!
# Adversary: Restarting with SCAN_PORT at 690.6s!
# Adversary: Start SCAN_PORT at 690.6s.
# Adversary: Processed SCAN_PORT at 715.6s.
# Adversary: Start EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 715.6s.
# Adversary: Processed EXPLOIT_VULN 4b2086bb-6660-4962-bb02-37b4c47bdff4 on host 0 at 723.6s.
# Adversary: Start EXPLOIT_VULN 96f60740-cab1-4acb-b5c9-f35df656a32e on host 0 at 723.6s.
# Adversary: Processed EXPLOIT_VULN 96f60740-cab1-4acb-b5c9-f35df656a32e on host 0 at 741.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 0 at 741.5s.
# Adversary: Processed EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 0 at 763.5s.
# Adversary: Host 0 has been compromised at 763.5s!
# Adversary: Start SCAN_NEIGHBOR at 763.5s.
# Adversary: Processed SCAN_NEIGHBOR at 768.5s.
# Adversary: Start ENUM_HOST at 768.5s.
# Adversary: Processed ENUM_HOST at 773.5s.
# Adversary: Start SCAN_PORT at 773.5s.
# Adversary: Processed SCAN_PORT at 798.5s.
# Adversary: Start EXPLOIT_VULN 07bbe11b-d98e-4f61-8cd3-1346e4ccd4f9 on host 14 at 798.5s.
# Adversary: Processed EXPLOIT_VULN 07bbe11b-d98e-4f61-8cd3-1346e4ccd4f9 on host 14 at 799.1s.
# Adversary: Start EXPLOIT_VULN c330cdbb-49e8-4eb0-89cf-f577976e9a49 on host 14 at 799.1s.
# Adversary: Processed EXPLOIT_VULN c330cdbb-49e8-4eb0-89cf-f577976e9a49 on host 14 at 800.2s.
# Adversary: Start EXPLOIT_VULN 3f4dd4af-6168-4ddb-8d9f-271c7fca67c2 on host 14 at 800.2s.
# MTD: IPShuffle triggered 800.4s
# MTD: IPShuffle deployed in the network at 800.4s.
# Adversary: Processed EXPLOIT_VULN 3f4dd4af-6168-4ddb-8d9f-271c7fca67c2 on host 14 at 804.3s.
# Adversary: Start EXPLOIT_VULN e4bcf7be-6870-4db2-8aff-2c5267e9750f on host 14 at 804.3s.
# Adversary: Processed EXPLOIT_VULN e4bcf7be-6870-4db2-8aff-2c5267e9750f on host 14 at 810.4s.
# Adversary: Start EXPLOIT_VULN 97acf71f-80fb-42a8-aab2-937ea375c2b8 on host 14 at 810.4s.
# Adversary: Processed EXPLOIT_VULN 97acf71f-80fb-42a8-aab2-937ea375c2b8 on host 14 at 818.2s.
# Adversary: Start EXPLOIT_VULN 62f4aa4b-04da-4096-8571-ab173b00a6ae on host 14 at 818.2s.
# Adversary: Processed EXPLOIT_VULN 62f4aa4b-04da-4096-8571-ab173b00a6ae on host 14 at 824.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e558f48b-94a0-4593-a979-e18e4e084501 on host 14 at 824.1s.
# Adversary: Processed EXPLOIT_VULN e558f48b-94a0-4593-a979-e18e4e084501 on host 14 at 826.8s.
# Adversary: Start EXPLOIT_VULN d5c63f12-0f01-4b03-a43d-c8bae3bf3227 on host 14 at 826.8s.
# Adversary: Processed EXPLOIT_VULN d5c63f12-0f01-4b03-a43d-c8bae3bf3227 on host 14 at 849.1s.
# Adversary: Start EXPLOIT_VULN 81ded3a8-1b7b-47c8-9164-5af37ccab4b7 on host 14 at 849.1s.
# Adversary: Processed EXPLOIT_VULN 81ded3a8-1b7b-47c8-9164-5af37ccab4b7 on host 14 at 857.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 14 at 857.7s.
# Adversary: Processed EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 14 at 875.3s.
# Adversary: Start EXPLOIT_VULN 5de9c90a-698c-4647-bf3c-b6767b2b9c41 on host 14 at 875.3s.
# Adversary: Processed EXPLOIT_VULN 5de9c90a-698c-4647-bf3c-b6767b2b9c41 on host 14 at 887.1s.
# Adversary: Host 14 has been compromised at 887.1s!
# Adversary: Start SCAN_NEIGHBOR at 887.1s.
# Adversary: Processed SCAN_NEIGHBOR at 892.1s.
# Adversary: Start ENUM_HOST at 892.1s.
# Adversary: Processed ENUM_HOST at 897.1s.
# Adversary: Start SCAN_PORT at 897.1s.
# MTD: IPShuffle finished in 110.2s at 910.5s.
# MTD: Interrupted SCAN_PORT at 910.5s!
# Adversary: Restarting with SCAN_HOST at 931.5s!
# Adversary: Start SCAN_HOST at 931.5s.
# Adversary: Processed SCAN_HOST at 936.5s.
# Adversary: Start ENUM_HOST at 936.5s.
# Adversary: Processed ENUM_HOST at 941.5s.
# Adversary: Start SCAN_PORT at 941.5s.
# Adversary: Processed SCAN_PORT at 966.5s.
# Adversary: Start EXPLOIT_VULN 981ab366-3da3-4a37-b367-94e9ee852d36 on host 6 at 966.5s.
# Adversary: Processed EXPLOIT_VULN 981ab366-3da3-4a37-b367-94e9ee852d36 on host 6 at 967.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cf12a25e-9788-4b3a-946d-804332c231ca on host 6 at 967.4s.
# Adversary: Processed EXPLOIT_VULN cf12a25e-9788-4b3a-946d-804332c231ca on host 6 at 968.2s.
# Adversary: Start EXPLOIT_VULN e558f48b-94a0-4593-a979-e18e4e084501 on host 6 at 968.2s.
# Adversary: Processed EXPLOIT_VULN e558f48b-94a0-4593-a979-e18e4e084501 on host 6 at 975.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d5c63f12-0f01-4b03-a43d-c8bae3bf3227 on host 6 at 975.9s.
# Adversary: Processed EXPLOIT_VULN d5c63f12-0f01-4b03-a43d-c8bae3bf3227 on host 6 at 984.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 42f223b0-f48c-474d-86f1-a144ec76a896 on host 6 at 984.9s.
# Adversary: Processed EXPLOIT_VULN 42f223b0-f48c-474d-86f1-a144ec76a896 on host 6 at 986.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 25a60a13-fcf5-441a-9250-63cb91398e1a on host 6 at 986.9s.
# MTD: ServiceDiversity triggered 1000.5s
# MTD: ServiceDiversity deployed in the network at 1000.5s.
# Adversary: Processed EXPLOIT_VULN 25a60a13-fcf5-441a-9250-63cb91398e1a on host 6 at 1009.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start BRUTE_FORCE at 1009.8s.
# Adversary: Processed BRUTE_FORCE at 1029.8s.
# Adversary: Start ENUM_HOST at 1029.8s.
# Adversary: Processed ENUM_HOST at 1034.8s.
# Adversary: Start SCAN_PORT at 1034.8s.
# Adversary: Processed SCAN_PORT at 1059.8s.
# Adversary: Start EXPLOIT_VULN 06a35e74-bb6d-40d4-ad02-13c7fe42fb79 on host 17 at 1059.8s.
# Adversary: Processed EXPLOIT_VULN 06a35e74-bb6d-40d4-ad02-13c7fe42fb79 on host 17 at 1062.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 567f7b32-1933-402e-b7d5-c6412833a253 on host 17 at 1062.9s.
# Adversary: Processed EXPLOIT_VULN 567f7b32-1933-402e-b7d5-c6412833a253 on host 17 at 1064.5s.
# Adversary: Start EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1064.5s.
# Adversary: Processed EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1068.4s.
# Adversary: Start EXPLOIT_VULN 56263267-b3ee-4ab9-afe9-e369e635a3da on host 17 at 1068.4s.
# MTD: ServiceDiversity finished in 70.2s at 1070.7s.
# MTD: Interrupted EXPLOIT_VULN at 1070.7s!
# Adversary: Restarting with SCAN_PORT at 1090.9s!
# Adversary: Start SCAN_PORT at 1090.9s.
# Adversary: Processed SCAN_PORT at 1115.9s.
# Adversary: Start EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1115.9s.
# Adversary: Processed EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1119.7s.
# Adversary: Start EXPLOIT_VULN 56263267-b3ee-4ab9-afe9-e369e635a3da on host 17 at 1119.7s.
# Adversary: Processed EXPLOIT_VULN 56263267-b3ee-4ab9-afe9-e369e635a3da on host 17 at 1129.4s.
# Adversary: Start EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1129.4s.
# Adversary: Processed EXPLOIT_VULN 573e2297-4b41-4340-a26a-a3e3bfccc2a2 on host 17 at 1131.3s.
# Adversary: Start EXPLOIT_VULN 56263267-b3ee-4ab9-afe9-e369e635a3da on host 17 at 1131.3s.
# Adversary: Processed EXPLOIT_VULN 56263267-b3ee-4ab9-afe9-e369e635a3da on host 17 at 1140.0s.
# Adversary: Start EXPLOIT_VULN 485fa0d4-bbd8-4caf-9bc3-d8ff6b1f6efc on host 17 at 1140.0s.
# Adversary: Processed EXPLOIT_VULN 485fa0d4-bbd8-4caf-9bc3-d8ff6b1f6efc on host 17 at 1144.8s.
# Adversary: Start EXPLOIT_VULN e375857c-0fac-43fd-9f78-dcda1ac1cf37 on host 17 at 1144.8s.
# Adversary: Processed EXPLOIT_VULN e375857c-0fac-43fd-9f78-dcda1ac1cf37 on host 17 at 1150.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9d1b91d6-43ed-4bb4-bec8-05f232291e44 on host 17 at 1150.9s.
# Adversary: Processed EXPLOIT_VULN 9d1b91d6-43ed-4bb4-bec8-05f232291e44 on host 17 at 1158.0s.
# Adversary: Start EXPLOIT_VULN e10909cb-5946-46ef-94ad-197b8a9c95fd on host 17 at 1158.0s.
# Adversary: Processed EXPLOIT_VULN e10909cb-5946-46ef-94ad-197b8a9c95fd on host 17 at 1166.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6bb263e7-96de-46bd-a02d-0648f1fab880 on host 17 at 1166.6s.
# Adversary: Processed EXPLOIT_VULN 6bb263e7-96de-46bd-a02d-0648f1fab880 on host 17 at 1172.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 56195a54-e374-4d53-8238-5176e2e3d4db on host 17 at 1172.0s.
# Adversary: Processed EXPLOIT_VULN 56195a54-e374-4d53-8238-5176e2e3d4db on host 17 at 1179.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 17 at 1179.7s.
# Adversary: Processed EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 17 at 1187.3s.
# Adversary: Host 17 has been compromised at 1187.3s!
# Adversary: Start SCAN_NEIGHBOR at 1187.3s.
# Adversary: Processed SCAN_NEIGHBOR at 1192.3s.
# Adversary: Start ENUM_HOST at 1192.3s.
# Adversary: Processed ENUM_HOST at 1197.3s.
# Adversary: Start ENUM_HOST at 1197.3s.
# MTD: OSDiversity triggered 1201.3s
# MTD: OSDiversity deployed in the network at 1201.3s.
# Adversary: Processed ENUM_HOST at 1202.3s.
# Adversary: Start SCAN_PORT at 1202.3s.
# Adversary: Processed SCAN_PORT at 1227.3s.
# Adversary: Start EXPLOIT_VULN 7eb054c9-4506-4a0a-9b37-a01fc1ec42f1 on host 11 at 1227.3s.
# Adversary: Processed EXPLOIT_VULN 7eb054c9-4506-4a0a-9b37-a01fc1ec42f1 on host 11 at 1233.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f896325e-005c-4570-81ae-e7dbe2ae3c65 on host 11 at 1233.2s.
# Adversary: Processed EXPLOIT_VULN f896325e-005c-4570-81ae-e7dbe2ae3c65 on host 11 at 1242.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e720331d-505e-482c-8206-6cd3f66580d1 on host 11 at 1242.9s.
# Adversary: Processed EXPLOIT_VULN e720331d-505e-482c-8206-6cd3f66580d1 on host 11 at 1251.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 11 at 1251.2s.
# Adversary: Processed EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 11 at 1273.4s.
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 11 at 1273.4s.
# MTD: OSDiversity finished in 80.4s at 1281.7s.
# MTD: Interrupted EXPLOIT_VULN at 1281.7s!
# Adversary: Restarting with SCAN_PORT at 1302.0s!
# Adversary: Start SCAN_PORT at 1302.0s.
# Adversary: Processed SCAN_PORT at 1327.0s.
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 11 at 1327.0s.
# Adversary: Processed EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 11 at 1349.3s.
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 11 at 1349.3s.
# Adversary: Processed EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 11 at 1371.5s.
# Adversary: Start EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 11 at 1371.5s.
# Adversary: Processed EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 11 at 1378.7s.
# Adversary: Start EXPLOIT_VULN 13708003-33b3-49fe-9c09-f8e6ded64960 on host 11 at 1378.7s.
# Adversary: Processed EXPLOIT_VULN 13708003-33b3-49fe-9c09-f8e6ded64960 on host 11 at 1378.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9d1b91d6-43ed-4bb4-bec8-05f232291e44 on host 11 at 1378.9s.
# Adversary: Processed EXPLOIT_VULN 9d1b91d6-43ed-4bb4-bec8-05f232291e44 on host 11 at 1386.9s.
# Adversary: Start EXPLOIT_VULN b32ef8fe-e9e6-4f38-9696-36b3ae292208 on host 11 at 1386.9s.
# Adversary: Processed EXPLOIT_VULN b32ef8fe-e9e6-4f38-9696-36b3ae292208 on host 11 at 1387.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 77777d08-0004-427e-8ea8-6fa645b9280e on host 11 at 1387.8s.
# Adversary: Processed EXPLOIT_VULN 77777d08-0004-427e-8ea8-6fa645b9280e on host 11 at 1393.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 11 at 1393.0s.
# MTD: ServiceDiversity triggered 1401.5s
# MTD: ServiceDiversity deployed in the network at 1401.5s.
# Adversary: Processed EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 11 at 1411.5s.
# Adversary: Start EXPLOIT_VULN 778aef9c-9fa2-41bd-ade7-46326afa96d0 on host 11 at 1411.5s.
# Adversary: Processed EXPLOIT_VULN 778aef9c-9fa2-41bd-ade7-46326afa96d0 on host 11 at 1423.4s.
# Adversary: Start EXPLOIT_VULN e98ad6ed-4708-49d9-bd94-1b5d4f0b0851 on host 11 at 1423.4s.
# Adversary: Processed EXPLOIT_VULN e98ad6ed-4708-49d9-bd94-1b5d4f0b0851 on host 11 at 1427.9s.
# Adversary: Start EXPLOIT_VULN 94f9dec2-aedb-4559-b7da-2d0c81af5f43 on host 11 at 1427.9s.
# Adversary: Processed EXPLOIT_VULN 94f9dec2-aedb-4559-b7da-2d0c81af5f43 on host 11 at 1429.0s.
# Adversary: Start EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 11 at 1429.0s.
# Adversary: Processed EXPLOIT_VULN 552447e3-5512-48de-ba0b-293debb717e8 on host 11 at 1436.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 11 has been compromised at 1436.1s!
# Adversary: Start SCAN_NEIGHBOR at 1436.1s.
# Adversary: Processed SCAN_NEIGHBOR at 1441.1s.
# Adversary: Start ENUM_HOST at 1441.1s.
# Adversary: Processed ENUM_HOST at 1446.1s.
# Adversary: Start SCAN_PORT at 1446.1s.
# Adversary: Processed SCAN_PORT at 1471.1s.
# Adversary: Host 13 has been compromised at 1471.1s!
# Adversary: Start SCAN_NEIGHBOR at 1471.1s.
# MTD: ServiceDiversity finished in 70.2s at 1471.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1476.1s.
# Adversary: Start ENUM_HOST at 1476.1s.
# Adversary: Processed ENUM_HOST at 1481.1s.
# Adversary: Start ENUM_HOST at 1481.1s.
# Adversary: Processed ENUM_HOST at 1486.1s.
# Adversary: Start ENUM_HOST at 1486.1s.
# Adversary: Processed ENUM_HOST at 1491.1s.
# Adversary: Start SCAN_PORT at 1491.1s.
# Adversary: Processed SCAN_PORT at 1516.1s.
# Adversary: Start EXPLOIT_VULN 0a83395a-df09-4ee1-9640-6f4801348483 on host 10 at 1516.1s.
# Adversary: Processed EXPLOIT_VULN 0a83395a-df09-4ee1-9640-6f4801348483 on host 10 at 1521.2s.
# Adversary: Start EXPLOIT_VULN 72df89f2-ee12-41cd-8a2b-0376cdf2a98d on host 10 at 1521.2s.
# Adversary: Processed EXPLOIT_VULN 72df89f2-ee12-41cd-8a2b-0376cdf2a98d on host 10 at 1526.5s.
# Adversary: Start EXPLOIT_VULN 39a1d74b-b927-40d8-8241-520d16b9a96b on host 10 at 1526.5s.
# Adversary: Processed EXPLOIT_VULN 39a1d74b-b927-40d8-8241-520d16b9a96b on host 10 at 1532.9s.
# Adversary: Start EXPLOIT_VULN 8443a1ab-66c2-4c8c-850a-20aebeff6d0c on host 10 at 1532.9s.
# Adversary: Processed EXPLOIT_VULN 8443a1ab-66c2-4c8c-850a-20aebeff6d0c on host 10 at 1539.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a24c123f-67cb-4d47-b49a-1c9a95782c1e on host 10 at 1539.3s.
# Adversary: Processed EXPLOIT_VULN a24c123f-67cb-4d47-b49a-1c9a95782c1e on host 10 at 1545.5s.
# Adversary: Start EXPLOIT_VULN 716306d2-90c3-4358-a3fa-42c816c2dc30 on host 10 at 1545.5s.
# Adversary: Processed EXPLOIT_VULN 716306d2-90c3-4358-a3fa-42c816c2dc30 on host 10 at 1550.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 10 has been compromised at 1550.9s!
# Adversary: Start SCAN_NEIGHBOR at 1550.9s.
# Adversary: Processed SCAN_NEIGHBOR at 1555.9s.
# Adversary: Start ENUM_HOST at 1555.9s.
# Adversary: Processed ENUM_HOST at 1560.9s.
# Adversary: Start ENUM_HOST at 1560.9s.
# Adversary: Processed ENUM_HOST at 1565.9s.
# Adversary: Start SCAN_PORT at 1565.9s.
# Adversary: Processed SCAN_PORT at 1590.9s.
# Adversary: Start EXPLOIT_VULN 248e9934-6b46-4823-a586-c2027a02a045 on host 16 at 1590.9s.
# Adversary: Processed EXPLOIT_VULN 248e9934-6b46-4823-a586-c2027a02a045 on host 16 at 1592.3s.
# Adversary: Start EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1592.3s.
# Adversary: Processed EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1598.6s.
# Adversary: Start EXPLOIT_VULN 1a9b1712-1f65-4fdd-ac91-8ad67beddc8c on host 16 at 1598.6s.
# MTD: ServiceDiversity triggered 1601.6s
# MTD: ServiceDiversity deployed in the network at 1601.6s.
# Adversary: Processed EXPLOIT_VULN 1a9b1712-1f65-4fdd-ac91-8ad67beddc8c on host 16 at 1603.4s.
# Adversary: Start EXPLOIT_VULN 51f54223-f83a-46f9-a442-29cf56aafcb7 on host 16 at 1603.4s.
# Adversary: Processed EXPLOIT_VULN 51f54223-f83a-46f9-a442-29cf56aafcb7 on host 16 at 1605.8s.
# Adversary: Start EXPLOIT_VULN 4353c651-702d-4b26-8205-7065d7d3722e on host 16 at 1605.8s.
# Adversary: Processed EXPLOIT_VULN 4353c651-702d-4b26-8205-7065d7d3722e on host 16 at 1607.7s.
# Adversary: Start EXPLOIT_VULN 2d28e744-43da-4dbc-8b62-95dc7674b11b on host 16 at 1607.7s.
# Adversary: Processed EXPLOIT_VULN 2d28e744-43da-4dbc-8b62-95dc7674b11b on host 16 at 1610.3s.
# Adversary: Start EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1610.3s.
# Adversary: Processed EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1617.9s.
# Adversary: Start EXPLOIT_VULN ab857b49-6265-450b-8919-2293c1ce15c9 on host 16 at 1617.9s.
# Adversary: Processed EXPLOIT_VULN ab857b49-6265-450b-8919-2293c1ce15c9 on host 16 at 1626.9s.
# Adversary: Start EXPLOIT_VULN 5ce45659-7314-4aa9-a713-8dee1e55a0e3 on host 16 at 1626.9s.
# Adversary: Processed EXPLOIT_VULN 5ce45659-7314-4aa9-a713-8dee1e55a0e3 on host 16 at 1633.3s.
# Adversary: Start EXPLOIT_VULN 83092ed3-fc59-4534-9951-a4ccedd48107 on host 16 at 1633.3s.
# Adversary: Processed EXPLOIT_VULN 83092ed3-fc59-4534-9951-a4ccedd48107 on host 16 at 1636.3s.
# Adversary: Start EXPLOIT_VULN 04c68740-079b-4e71-b916-b61fbe88a7fb on host 16 at 1636.3s.
# Adversary: Processed EXPLOIT_VULN 04c68740-079b-4e71-b916-b61fbe88a7fb on host 16 at 1643.4s.
# Adversary: Start EXPLOIT_VULN 8be09857-51ba-4d29-af13-295d8b1900da on host 16 at 1643.4s.
# Adversary: Processed EXPLOIT_VULN 8be09857-51ba-4d29-af13-295d8b1900da on host 16 at 1650.4s.
# Adversary: Start EXPLOIT_VULN 15ec747b-03ea-44f1-acaa-a3f79c96b4dd on host 16 at 1650.4s.
# Adversary: Processed EXPLOIT_VULN 15ec747b-03ea-44f1-acaa-a3f79c96b4dd on host 16 at 1657.2s.
# Adversary: Start EXPLOIT_VULN 54f07a7e-6a97-4c01-863c-5cfcf6aa0047 on host 16 at 1657.2s.
# Adversary: Processed EXPLOIT_VULN 54f07a7e-6a97-4c01-863c-5cfcf6aa0047 on host 16 at 1662.4s.
# Adversary: Start EXPLOIT_VULN 11925648-2fad-4a4b-bb42-e34a14a81581 on host 16 at 1662.4s.
# Adversary: Processed EXPLOIT_VULN 11925648-2fad-4a4b-bb42-e34a14a81581 on host 16 at 1667.7s.
# Adversary: Start EXPLOIT_VULN f3b9858d-c06d-4d33-b650-a2368979cf97 on host 16 at 1667.7s.
# MTD: ServiceDiversity finished in 70.4s at 1672.0s.
# MTD: Interrupted EXPLOIT_VULN at 1672.0s!
# Adversary: Restarting with SCAN_PORT at 1692.1s!
# Adversary: Start SCAN_PORT at 1692.1s.
# Adversary: Processed SCAN_PORT at 1717.1s.
# Adversary: Start EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1717.1s.
# Adversary: Processed EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1722.8s.
# Adversary: Start EXPLOIT_VULN f3b9858d-c06d-4d33-b650-a2368979cf97 on host 16 at 1722.8s.
# Adversary: Processed EXPLOIT_VULN f3b9858d-c06d-4d33-b650-a2368979cf97 on host 16 at 1730.4s.
# Adversary: Start EXPLOIT_VULN 131ab83b-47fd-4d36-9b6a-d6f6b71f442d on host 16 at 1730.4s.
# Adversary: Processed EXPLOIT_VULN 131ab83b-47fd-4d36-9b6a-d6f6b71f442d on host 16 at 1738.6s.
# Adversary: Start EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1738.6s.
# Adversary: Processed EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1746.6s.
# Adversary: Start EXPLOIT_VULN df152e8d-ac52-49b4-b15d-7700139848da on host 16 at 1746.6s.
# Adversary: Processed EXPLOIT_VULN df152e8d-ac52-49b4-b15d-7700139848da on host 16 at 1758.0s.
# Adversary: Start EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1758.0s.
# Adversary: Processed EXPLOIT_VULN 289f7b03-042f-4b1e-b1d4-81c2825ea258 on host 16 at 1762.1s.
# Adversary: Start EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1762.1s.
# Adversary: Processed EXPLOIT_VULN 5a511fbf-12ae-4669-9073-d0823e486d02 on host 16 at 1765.9s.
# Adversary: Start EXPLOIT_VULN df152e8d-ac52-49b4-b15d-7700139848da on host 16 at 1765.9s.
# Adversary: Processed EXPLOIT_VULN df152e8d-ac52-49b4-b15d-7700139848da on host 16 at 1770.2s.
# Adversary: Host 16 has been compromised at 1770.2s!
# Adversary: Start SCAN_NEIGHBOR at 1770.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1775.2s.
# Adversary: Start ENUM_HOST at 1775.2s.
# Adversary: Processed ENUM_HOST at 1780.2s.
# Adversary: Start SCAN_PORT at 1780.2s.
# MTD: ServiceDiversity triggered 1801.9s
# MTD: ServiceDiversity deployed in the network at 1801.9s.
# Adversary: Processed SCAN_PORT at 1805.2s.
# Adversary: Start EXPLOIT_VULN 0eb5c48d-3ddc-46c9-83f2-10da386a32fa on host 7 at 1805.2s.
# Adversary: Processed EXPLOIT_VULN 0eb5c48d-3ddc-46c9-83f2-10da386a32fa on host 7 at 1806.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0b9930f3-c048-44fc-93b7-85406e0053dc on host 7 at 1806.0s.
# Adversary: Processed EXPLOIT_VULN 0b9930f3-c048-44fc-93b7-85406e0053dc on host 7 at 1806.8s.
# Adversary: Start EXPLOIT_VULN 1bac9d25-1e71-47c3-b8cd-447d36cac002 on host 7 at 1806.8s.
# Adversary: Processed EXPLOIT_VULN 1bac9d25-1e71-47c3-b8cd-447d36cac002 on host 7 at 1826.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 43aa2987-2f8d-4deb-980e-f60a83bf3e23 on host 7 at 1826.9s.
# Adversary: Processed EXPLOIT_VULN 43aa2987-2f8d-4deb-980e-f60a83bf3e23 on host 7 at 1835.8s.
# Adversary: Start EXPLOIT_VULN 6db2dae1-d240-4278-b91c-5ed5ee414ac6 on host 7 at 1835.8s.
# Adversary: Processed EXPLOIT_VULN 6db2dae1-d240-4278-b91c-5ed5ee414ac6 on host 7 at 1842.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 16b1c0c4-3a3f-4a20-a064-43840393c42c on host 7 at 1842.7s.
# Adversary: Processed EXPLOIT_VULN 16b1c0c4-3a3f-4a20-a064-43840393c42c on host 7 at 1844.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN db3e01ae-dc07-4b13-b0c4-5d1b79911638 on host 7 at 1844.0s.
# Adversary: Processed EXPLOIT_VULN db3e01ae-dc07-4b13-b0c4-5d1b79911638 on host 7 at 1847.3s.
# Adversary: Start EXPLOIT_VULN 89b3144e-3f65-44cf-ae11-fc47f4711d85 on host 7 at 1847.3s.
# Adversary: Processed EXPLOIT_VULN 89b3144e-3f65-44cf-ae11-fc47f4711d85 on host 7 at 1853.4s.
# Adversary: Start EXPLOIT_VULN 7fd1bd3f-3cae-494c-b921-2c2e8ccd445a on host 7 at 1853.4s.
# Adversary: Processed EXPLOIT_VULN 7fd1bd3f-3cae-494c-b921-2c2e8ccd445a on host 7 at 1860.5s.
# Adversary: Start EXPLOIT_VULN cc6a740d-035d-43fd-ba8b-d159cc25e7c6 on host 7 at 1860.5s.
# Adversary: Processed EXPLOIT_VULN cc6a740d-035d-43fd-ba8b-d159cc25e7c6 on host 7 at 1868.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN faf2d3fb-979c-4642-a903-87d12927e98f on host 7 at 1868.5s.
# Adversary: Processed EXPLOIT_VULN faf2d3fb-979c-4642-a903-87d12927e98f on host 7 at 1869.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 7 at 1869.3s.
# MTD: ServiceDiversity finished in 70.1s at 1872.0s.
# MTD: Interrupted EXPLOIT_VULN at 1872.0s!
# Adversary: Restarting with SCAN_PORT at 1892.5s!
# Adversary: Start SCAN_PORT at 1892.5s.
# Adversary: Processed SCAN_PORT at 1917.5s.
# Adversary: Start EXPLOIT_VULN 89b3144e-3f65-44cf-ae11-fc47f4711d85 on host 7 at 1917.5s.
# Adversary: Processed EXPLOIT_VULN 89b3144e-3f65-44cf-ae11-fc47f4711d85 on host 7 at 1923.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7fd1bd3f-3cae-494c-b921-2c2e8ccd445a on host 7 at 1923.9s.
# Adversary: Processed EXPLOIT_VULN 7fd1bd3f-3cae-494c-b921-2c2e8ccd445a on host 7 at 1930.8s.
# Adversary: Start EXPLOIT_VULN 301ee833-db15-4868-bac4-e4e6454ff9fa on host 7 at 1930.8s.
# Adversary: Processed EXPLOIT_VULN 301ee833-db15-4868-bac4-e4e6454ff9fa on host 7 at 1939.2s.
# Adversary: Start EXPLOIT_VULN 43aa2987-2f8d-4deb-980e-f60a83bf3e23 on host 7 at 1939.2s.
# Adversary: Processed EXPLOIT_VULN 43aa2987-2f8d-4deb-980e-f60a83bf3e23 on host 7 at 1947.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 7 at 1947.0s.
# Adversary: Processed EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 7 at 1968.7s.
# Adversary: Start EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 7 at 1968.7s.
# Adversary: Processed EXPLOIT_VULN 31254ffa-5145-4769-ad13-6ee622b88f68 on host 7 at 1991.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 7 has been compromised at 1991.3s!
# Adversary: Start SCAN_NEIGHBOR at 1991.3s.
# Adversary: Processed SCAN_NEIGHBOR at 1996.3s.
# Adversary: Start ENUM_HOST at 1996.3s.
# Adversary: Processed ENUM_HOST at 2001.3s.
# Adversary: Start SCAN_PORT at 2001.3s.
# MTD: OSDiversity triggered 2002.3s
# MTD: OSDiversity deployed in the network at 2002.3s.
# Adversary: Processed SCAN_PORT at 2026.3s.
# Adversary: Host 22 has been compromised at 2026.3s!
# Adversary: Start SCAN_NEIGHBOR at 2026.3s.
# Adversary: Processed SCAN_NEIGHBOR at 2031.3s.
# Adversary: Start ENUM_HOST at 2031.3s.
# Adversary: Processed ENUM_HOST at 2036.3s.
# Adversary: Start ENUM_HOST at 2036.3s.
# Adversary: Processed ENUM_HOST at 2041.3s.
# Adversary: Start SCAN_PORT at 2041.3s.
# Adversary: Processed SCAN_PORT at 2066.3s.
# Adversary: Start EXPLOIT_VULN ee82c746-b395-403f-a73f-ac64aa07018c on host 15 at 2066.3s.
# Adversary: Processed EXPLOIT_VULN ee82c746-b395-403f-a73f-ac64aa07018c on host 15 at 2067.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6fe31827-854e-426f-9d8a-d62266377ac2 on host 15 at 2067.1s.
# Adversary: Processed EXPLOIT_VULN 6fe31827-854e-426f-9d8a-d62266377ac2 on host 15 at 2072.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN fdde802b-7e15-45c2-9c17-4f184abd84a2 on host 15 at 2072.6s.
# Adversary: Processed EXPLOIT_VULN fdde802b-7e15-45c2-9c17-4f184abd84a2 on host 15 at 2073.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cb7db8e1-b5a4-4d84-94f2-a8f29a9a2e1c on host 15 at 2073.6s.
# Adversary: Processed EXPLOIT_VULN cb7db8e1-b5a4-4d84-94f2-a8f29a9a2e1c on host 15 at 2075.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2b2911eb-3a02-45fa-9f44-a564282f1353 on host 15 at 2075.6s.
# MTD: OSDiversity finished in 80.0s at 2082.3s.
# MTD: Interrupted EXPLOIT_VULN at 2082.3s!
# Adversary: Restarting with SCAN_PORT at 2102.5s!
# Adversary: Start SCAN_PORT at 2102.5s.
# Adversary: Processed SCAN_PORT at 2127.5s.
# Adversary: Start EXPLOIT_VULN b545df1d-bd83-4e9e-869a-4df270524b6b on host 15 at 2127.5s.
# Adversary: Processed EXPLOIT_VULN b545df1d-bd83-4e9e-869a-4df270524b6b on host 15 at 2128.9s.
# Adversary: Start EXPLOIT_VULN 089283f6-6601-41e8-99ca-39a9f5168b16 on host 15 at 2128.9s.
# Adversary: Processed EXPLOIT_VULN 089283f6-6601-41e8-99ca-39a9f5168b16 on host 15 at 2130.6s.
# Adversary: Start EXPLOIT_VULN 698226d1-4659-49bf-babd-b2e953ff52f9 on host 15 at 2130.6s.
# Adversary: Processed EXPLOIT_VULN 698226d1-4659-49bf-babd-b2e953ff52f9 on host 15 at 2132.2s.
# Adversary: Start EXPLOIT_VULN 24b7d8dd-9eff-49f0-8a70-14e9e3c52887 on host 15 at 2132.2s.
# Adversary: Processed EXPLOIT_VULN 24b7d8dd-9eff-49f0-8a70-14e9e3c52887 on host 15 at 2133.6s.
# Adversary: Start EXPLOIT_VULN 771f552d-711b-46fb-9f6e-f52f0b61032e on host 15 at 2133.6s.
# Adversary: Processed EXPLOIT_VULN 771f552d-711b-46fb-9f6e-f52f0b61032e on host 15 at 2134.8s.
# Adversary: Start EXPLOIT_VULN 3d8bd264-0bde-484a-a205-057b3455bbd4 on host 15 at 2134.8s.
# Adversary: Processed EXPLOIT_VULN 3d8bd264-0bde-484a-a205-057b3455bbd4 on host 15 at 2135.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7b3e14a3-5c09-45f7-86aa-9c6531a4caf5 on host 15 at 2135.4s.
# Adversary: Processed EXPLOIT_VULN 7b3e14a3-5c09-45f7-86aa-9c6531a4caf5 on host 15 at 2140.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5441cfb6-e377-481d-b2c5-0965919cc6fd on host 15 at 2140.7s.
# Adversary: Processed EXPLOIT_VULN 5441cfb6-e377-481d-b2c5-0965919cc6fd on host 15 at 2150.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5544682a-9949-4cd1-9104-ac6093e29c5a on host 15 at 2150.4s.
# Adversary: Processed EXPLOIT_VULN 5544682a-9949-4cd1-9104-ac6093e29c5a on host 15 at 2157.8s.
# Adversary: Start EXPLOIT_VULN 643bdc25-5258-43f8-844b-808d02eefb5e on host 15 at 2157.8s.
# Adversary: Processed EXPLOIT_VULN 643bdc25-5258-43f8-844b-808d02eefb5e on host 15 at 2164.8s.
# Adversary: Start EXPLOIT_VULN fffe2e2e-8427-4ae0-acda-65649a3cd0f2 on host 15 at 2164.8s.
# Adversary: Processed EXPLOIT_VULN fffe2e2e-8427-4ae0-acda-65649a3cd0f2 on host 15 at 2165.6s.
# Adversary: Start EXPLOIT_VULN 3b187572-bf9d-470b-ab67-69bf5683f99f on host 15 at 2165.6s.
# Adversary: Processed EXPLOIT_VULN 3b187572-bf9d-470b-ab67-69bf5683f99f on host 15 at 2167.3s.
# Adversary: Start EXPLOIT_VULN d78ce262-9193-4b67-bdee-8af5f9ad3c42 on host 15 at 2167.3s.
# Adversary: Processed EXPLOIT_VULN d78ce262-9193-4b67-bdee-8af5f9ad3c42 on host 15 at 2168.2s.
# Adversary: Start EXPLOIT_VULN 8371f043-009d-4627-b961-cc9ac6faef49 on host 15 at 2168.2s.
# Adversary: Processed EXPLOIT_VULN 8371f043-009d-4627-b961-cc9ac6faef49 on host 15 at 2170.2s.
# Adversary: Start EXPLOIT_VULN 302cef4e-1a72-4870-9932-a691cd78f3b4 on host 15 at 2170.2s.
# Adversary: Processed EXPLOIT_VULN 302cef4e-1a72-4870-9932-a691cd78f3b4 on host 15 at 2172.8s.
# Adversary: Start EXPLOIT_VULN 2366ead6-abbd-4671-bb80-aedbceac7266 on host 15 at 2172.8s.
# Adversary: Processed EXPLOIT_VULN 2366ead6-abbd-4671-bb80-aedbceac7266 on host 15 at 2175.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9d6f515c-016e-4d60-9688-9f2c87c88f36 on host 15 at 2175.9s.
# Adversary: Processed EXPLOIT_VULN 9d6f515c-016e-4d60-9688-9f2c87c88f36 on host 15 at 2180.6s.
# Adversary: Start EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 15 at 2180.6s.
# Adversary: Processed EXPLOIT_VULN 57b50450-5789-4b01-ae53-e9112e3f45af on host 15 at 2198.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 778aef9c-9fa2-41bd-ade7-46326afa96d0 on host 15 at 2198.7s.
# MTD: OSDiversity triggered 2202.5s
# MTD: OSDiversity deployed in the network at 2202.5s.
# Adversary: Processed EXPLOIT_VULN 778aef9c-9fa2-41bd-ade7-46326afa96d0 on host 15 at 2209.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1739694a-c372-47e6-a5c5-4dbbfd645fbe on host 15 at 2209.9s.
# Adversary: Processed EXPLOIT_VULN 1739694a-c372-47e6-a5c5-4dbbfd645fbe on host 15 at 2218.1s.
# Adversary: Start EXPLOIT_VULN ed34a9c3-0e68-482c-8560-c0129957396e on host 15 at 2218.1s.
# Adversary: Processed EXPLOIT_VULN ed34a9c3-0e68-482c-8560-c0129957396e on host 15 at 2220.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1d48abad-ac54-42bd-a571-cc832fc2f683 on host 15 at 2220.1s.
# Adversary: Processed EXPLOIT_VULN 1d48abad-ac54-42bd-a571-cc832fc2f683 on host 15 at 2221.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0f882f02-e511-47b8-8425-a790217c05a3 on host 15 at 2221.5s.
# Adversary: Processed EXPLOIT_VULN 0f882f02-e511-47b8-8425-a790217c05a3 on host 15 at 2229.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 89881a7e-01d6-449c-97dc-9447444044d7 on host 15 at 2229.3s.
# Adversary: Processed EXPLOIT_VULN 89881a7e-01d6-449c-97dc-9447444044d7 on host 15 at 2240.2s.
# Adversary: Start EXPLOIT_VULN eb9be415-b3bc-4392-9b46-5d3e8199b5dd on host 15 at 2240.2s.
# Adversary: Processed EXPLOIT_VULN eb9be415-b3bc-4392-9b46-5d3e8199b5dd on host 15 at 2261.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2261.1s.
# Adversary: Processed EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2265.6s.
# Adversary: Start EXPLOIT_VULN 85b19808-f430-4343-a74e-2862a4012869 on host 15 at 2265.6s.
# Adversary: Processed EXPLOIT_VULN 85b19808-f430-4343-a74e-2862a4012869 on host 15 at 2270.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2270.2s.
# Adversary: Processed EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2279.6s.
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 15 at 2279.6s.
# MTD: OSDiversity finished in 81.7s at 2284.2s.
# MTD: Interrupted EXPLOIT_VULN at 2284.2s!
# Adversary: Restarting with SCAN_PORT at 2304.6s!
# Adversary: Start SCAN_PORT at 2304.6s.
# Adversary: Processed SCAN_PORT at 2329.6s.
# Adversary: Start EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2329.6s.
# Adversary: Processed EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2332.4s.
# Adversary: Start EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2332.4s.
# Adversary: Processed EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2341.7s.
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 15 at 2341.7s.
# Adversary: Processed EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 15 at 2363.9s.
# Adversary: Start EXPLOIT_VULN d78ce262-9193-4b67-bdee-8af5f9ad3c42 on host 15 at 2363.9s.
# Adversary: Processed EXPLOIT_VULN d78ce262-9193-4b67-bdee-8af5f9ad3c42 on host 15 at 2364.5s.
# Adversary: Start EXPLOIT_VULN 18f577b5-c9c5-4235-9262-5f03f242bb9f on host 15 at 2364.5s.
# Adversary: Processed EXPLOIT_VULN 18f577b5-c9c5-4235-9262-5f03f242bb9f on host 15 at 2368.2s.
# Adversary: Start EXPLOIT_VULN 20d45ae2-c9f0-444b-8b01-c42e8327da7d on host 15 at 2368.2s.
# Adversary: Processed EXPLOIT_VULN 20d45ae2-c9f0-444b-8b01-c42e8327da7d on host 15 at 2372.7s.
# Adversary: Start EXPLOIT_VULN 37985c5c-92f6-4b71-bf15-ae00b8976d39 on host 15 at 2372.7s.
# Adversary: Processed EXPLOIT_VULN 37985c5c-92f6-4b71-bf15-ae00b8976d39 on host 15 at 2379.3s.
# Adversary: Start EXPLOIT_VULN 025fb463-2a43-48a2-815a-11d653d9d86e on host 15 at 2379.3s.
# Adversary: Processed EXPLOIT_VULN 025fb463-2a43-48a2-815a-11d653d9d86e on host 15 at 2387.6s.
# Adversary: Start EXPLOIT_VULN f52316b5-1423-475c-bc48-3a64c61c0a67 on host 15 at 2387.6s.
# Adversary: Processed EXPLOIT_VULN f52316b5-1423-475c-bc48-3a64c61c0a67 on host 15 at 2390.4s.
# Adversary: Start EXPLOIT_VULN e5061b4f-292c-419b-8243-92d4f60870f0 on host 15 at 2390.4s.
# Adversary: Processed EXPLOIT_VULN e5061b4f-292c-419b-8243-92d4f60870f0 on host 15 at 2396.7s.
# Adversary: Start EXPLOIT_VULN 658885ee-de18-496e-af00-3aea939ee606 on host 15 at 2396.7s.
# MTD: ServiceDiversity triggered 2403.6s
# MTD: ServiceDiversity deployed in the network at 2403.6s.
# Adversary: Processed EXPLOIT_VULN 658885ee-de18-496e-af00-3aea939ee606 on host 15 at 2404.6s.
# Adversary: Start EXPLOIT_VULN 921a23bb-8ae0-45af-992a-c9b65166fca9 on host 15 at 2404.6s.
# Adversary: Processed EXPLOIT_VULN 921a23bb-8ae0-45af-992a-c9b65166fca9 on host 15 at 2412.2s.
# Adversary: Start EXPLOIT_VULN 5544682a-9949-4cd1-9104-ac6093e29c5a on host 15 at 2412.2s.
# Adversary: Processed EXPLOIT_VULN 5544682a-9949-4cd1-9104-ac6093e29c5a on host 15 at 2418.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 288af518-1206-4825-877c-b5c4a08479ce on host 15 at 2418.6s.
# Adversary: Processed EXPLOIT_VULN 288af518-1206-4825-877c-b5c4a08479ce on host 15 at 2435.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a283acb7-2b5c-4998-ac31-6286d0ae1a1e on host 15 at 2435.7s.
# Adversary: Processed EXPLOIT_VULN a283acb7-2b5c-4998-ac31-6286d0ae1a1e on host 15 at 2442.8s.
# Adversary: Start EXPLOIT_VULN 5b95048c-8725-4041-baf7-9a5ded795332 on host 15 at 2442.8s.
# Adversary: Processed EXPLOIT_VULN 5b95048c-8725-4041-baf7-9a5ded795332 on host 15 at 2457.0s.
# Adversary: Start EXPLOIT_VULN ca65693e-3976-4392-8623-78d42efeb291 on host 15 at 2457.0s.
# Adversary: Processed EXPLOIT_VULN ca65693e-3976-4392-8623-78d42efeb291 on host 15 at 2471.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 89881a7e-01d6-449c-97dc-9447444044d7 on host 15 at 2471.2s.
# MTD: ServiceDiversity finished in 70.8s at 2474.4s.
# MTD: Interrupted EXPLOIT_VULN at 2474.4s!
# Adversary: Restarting with SCAN_PORT at 2494.4s!
# Adversary: Start SCAN_PORT at 2494.4s.
# Adversary: Processed SCAN_PORT at 2519.4s.
# Adversary: Start EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2519.4s.
# Adversary: Processed EXPLOIT_VULN 1b110961-8992-468e-96f7-d061ff67b7a2 on host 15 at 2522.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2522.4s.
# Adversary: Processed EXPLOIT_VULN 004271a6-b9e5-45df-b186-947f0761afa4 on host 15 at 2531.7s.
# Adversary: Start EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 15 at 2531.7s.
# Adversary: Processed EXPLOIT_VULN 9e28388c-f3c8-4aba-9d78-1ad8087668d1 on host 15 at 2553.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 658885ee-de18-496e-af00-3aea939ee606 on host 15 at 2553.6s.
# Adversary: Processed EXPLOIT_VULN 658885ee-de18-496e-af00-3aea939ee606 on host 15 at 2563.6s.
# Adversary: Start EXPLOIT_VULN 1ce1fa72-e8f2-4511-9752-04080a46d8f5 on host 15 at 2563.6s.
# Adversary: Processed EXPLOIT_VULN 1ce1fa72-e8f2-4511-9752-04080a46d8f5 on host 15 at 2571.1s.
# Adversary: Start EXPLOIT_VULN e479c9f3-d475-4bce-a2bb-1c19309c22f3 on host 15 at 2571.1s.
# Adversary: Processed EXPLOIT_VULN e479c9f3-d475-4bce-a2bb-1c19309c22f3 on host 15 at 2579.3s.
# Adversary: Start EXPLOIT_VULN 447ce68c-b864-41cf-951e-fca241daafda on host 15 at 2579.3s.
# Adversary: Processed EXPLOIT_VULN 447ce68c-b864-41cf-951e-fca241daafda on host 15 at 2588.3s.
# Adversary: Start EXPLOIT_VULN 89881a7e-01d6-449c-97dc-9447444044d7 on host 15 at 2588.3s.
# Adversary: Processed EXPLOIT_VULN 89881a7e-01d6-449c-97dc-9447444044d7 on host 15 at 2597.0s.
# Adversary: Start EXPLOIT_VULN 96adbe6a-9bb0-442f-b839-014221a8f86f on host 15 at 2597.0s.
# MTD: CompleteTopologyShuffle triggered 2603.8s
# MTD: CompleteTopologyShuffle deployed in the network at 2603.8s.
# Adversary: Processed EXPLOIT_VULN 96adbe6a-9bb0-442f-b839-014221a8f86f on host 15 at 2604.9s.
# Adversary: Start EXPLOIT_VULN 5b95048c-8725-4041-baf7-9a5ded795332 on host 15 at 2604.9s.
# Adversary: Processed EXPLOIT_VULN 5b95048c-8725-4041-baf7-9a5ded795332 on host 15 at 2619.3s.
# Adversary: Start EXPLOIT_VULN 0a81ee06-9e32-417c-a548-1a5ebebe76ff on host 15 at 2619.3s.
# Adversary: Processed EXPLOIT_VULN 0a81ee06-9e32-417c-a548-1a5ebebe76ff on host 15 at 2625.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d34adf94-4bfb-450f-8b82-39c9337ebcdb on host 15 at 2625.9s.
# Adversary: Processed EXPLOIT_VULN d34adf94-4bfb-450f-8b82-39c9337ebcdb on host 15 at 2630.4s.
# Adversary: Start EXPLOIT_VULN 025fb463-2a43-48a2-815a-11d653d9d86e on host 15 at 2630.4s.
# Adversary: Processed EXPLOIT_VULN 025fb463-2a43-48a2-815a-11d653d9d86e on host 15 at 2638.5s.
# Adversary: Start EXPLOIT_VULN 4c4fef38-1dbf-4a75-b62d-7f61f50450df on host 15 at 2638.5s.
# Adversary: Processed EXPLOIT_VULN 4c4fef38-1dbf-4a75-b62d-7f61f50450df on host 15 at 2647.2s.
# Adversary: Start EXPLOIT_VULN 2b2911eb-3a02-45fa-9f44-a564282f1353 on host 15 at 2647.2s.
# Adversary: Processed EXPLOIT_VULN 2b2911eb-3a02-45fa-9f44-a564282f1353 on host 15 at 2663.4s.
# Adversary: Start EXPLOIT_VULN 831ab2ef-dcf1-46f9-a7d3-2fb4ff88b3a3 on host 15 at 2663.4s.
# Adversary: Processed EXPLOIT_VULN 831ab2ef-dcf1-46f9-a7d3-2fb4ff88b3a3 on host 15 at 2664.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2b2911eb-3a02-45fa-9f44-a564282f1353 on host 15 at 2664.7s.
# Adversary: Processed EXPLOIT_VULN 2b2911eb-3a02-45fa-9f44-a564282f1353 on host 15 at 2681.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 831ab2ef-dcf1-46f9-a7d3-2fb4ff88b3a3 on host 15 at 2681.5s.
# Adversary: Processed EXPLOIT_VULN 831ab2ef-dcf1-46f9-a7d3-2fb4ff88b3a3 on host 15 at 2682.8s.
# Adversary: Start EXPLOIT_VULN 1739694a-c372-47e6-a5c5-4dbbfd645fbe on host 15 at 2682.8s.
# Adversary: Processed EXPLOIT_VULN 1739694a-c372-47e6-a5c5-4dbbfd645fbe on host 15 at 2691.1s.
# Adversary: Start EXPLOIT_VULN 1fbb555e-1db2-4f23-9eec-8a7797712f21 on host 15 at 2691.1s.
# Adversary: Processed EXPLOIT_VULN 1fbb555e-1db2-4f23-9eec-8a7797712f21 on host 15 at 2691.2s.
# Adversary: Start EXPLOIT_VULN b57fe292-3f21-45f1-ab66-083041cf3e42 on host 15 at 2691.2s.
# Adversary: Processed EXPLOIT_VULN b57fe292-3f21-45f1-ab66-083041cf3e42 on host 15 at 2694.8s.
# Adversary: Start EXPLOIT_VULN 0382dfd3-609c-47d7-a9d0-ea5a27fd794b on host 15 at 2694.8s.
# Adversary: Processed EXPLOIT_VULN 0382dfd3-609c-47d7-a9d0-ea5a27fd794b on host 15 at 2700.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c7f93663-8494-4d1f-8ae9-ace4f45ae854 on host 15 at 2700.8s.
# Adversary: Processed EXPLOIT_VULN c7f93663-8494-4d1f-8ae9-ace4f45ae854 on host 15 at 2705.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 04004348-2ad9-4c9b-a92a-be5f597452d2 on host 15 at 2705.9s.
# Adversary: Processed EXPLOIT_VULN 04004348-2ad9-4c9b-a92a-be5f597452d2 on host 15 at 2720.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9b6f1bfd-64bf-4462-8a0f-3ef4d901bd3b on host 15 at 2720.7s.
# Adversary: Processed EXPLOIT_VULN 9b6f1bfd-64bf-4462-8a0f-3ef4d901bd3b on host 15 at 2721.5s.
# Adversary: Start EXPLOIT_VULN cb83a2d1-26cb-4a11-83d9-70ab969fa318 on host 15 at 2721.5s.
# Adversary: Processed EXPLOIT_VULN cb83a2d1-26cb-4a11-83d9-70ab969fa318 on host 15 at 2721.8s.
# Adversary: Start EXPLOIT_VULN 68180dfc-1957-48d3-b746-2147f2443ead on host 15 at 2721.8s.
# Adversary: Processed EXPLOIT_VULN 68180dfc-1957-48d3-b746-2147f2443ead on host 15 at 2722.3s.
# Adversary: Start EXPLOIT_VULN 871a3062-cb7f-4f3f-ac1f-2d0bcd92620a on host 15 at 2722.3s.
# MTD: CompleteTopologyShuffle finished in 120.2s at 2724.0s.
# MTD: Interrupted EXPLOIT_VULN at 2724.0s!
# Adversary: Restarting with SCAN_HOST at 2744.0s!
# Adversary: Start SCAN_HOST at 2744.0s.
# Adversary: Processed SCAN_HOST at 2749.0s.
# Adversary: Start ENUM_HOST at 2749.0s.
# Adversary: Processed ENUM_HOST at 2754.0s.
# Adversary: Start SCAN_PORT at 2754.0s.
# Adversary: Processed SCAN_PORT at 2779.0s.
# Adversary: Host 6 has been compromised at 2779.0s!
# Adversary: Start SCAN_NEIGHBOR at 2779.0s.
# Adversary: Processed SCAN_NEIGHBOR at 2784.0s.
# Adversary: Start ENUM_HOST at 2784.0s.
# Adversary: Processed ENUM_HOST at 2789.0s.
# Adversary: Start ENUM_HOST at 2789.0s.
# Adversary: Processed ENUM_HOST at 2794.0s.
# Adversary: Start SCAN_PORT at 2794.0s.
# MTD: CompleteTopologyShuffle triggered 2803.9s
# MTD: CompleteTopologyShuffle deployed in the network at 2803.9s.
# Adversary: Processed SCAN_PORT at 2819.0s.
# Adversary: Start EXPLOIT_VULN f0357cd0-2b33-4670-a09d-92765f7ab589 on host 25 at 2819.0s.
# Adversary: Processed EXPLOIT_VULN f0357cd0-2b33-4670-a09d-92765f7ab589 on host 25 at 2819.8s.
# Adversary: Start EXPLOIT_VULN 40b8b207-b52b-4d2b-90f4-22911be8faca on host 25 at 2819.8s.
# Adversary: Processed EXPLOIT_VULN 40b8b207-b52b-4d2b-90f4-22911be8faca on host 25 at 2823.1s.
# Adversary: Start EXPLOIT_VULN aeac1bbe-e8de-46c4-8e16-799becfbe62c on host 25 at 2823.1s.
# Adversary: Processed EXPLOIT_VULN aeac1bbe-e8de-46c4-8e16-799becfbe62c on host 25 at 2830.2s.
# Adversary: Start EXPLOIT_VULN 6875e736-fd0e-44ab-95c0-8b053466b806 on host 25 at 2830.2s.
# Adversary: Processed EXPLOIT_VULN 6875e736-fd0e-44ab-95c0-8b053466b806 on host 25 at 2838.3s.
# Adversary: Start EXPLOIT_VULN 5d2b21bc-3d17-46d5-8b47-33117e113010 on host 25 at 2838.3s.
# Adversary: Processed EXPLOIT_VULN 5d2b21bc-3d17-46d5-8b47-33117e113010 on host 25 at 2841.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9f3a9e44-6f99-4da5-998d-985bacf3b946 on host 25 at 2841.9s.
# Adversary: Processed EXPLOIT_VULN 9f3a9e44-6f99-4da5-998d-985bacf3b946 on host 25 at 2847.5s.
# Adversary: Start EXPLOIT_VULN d0693a6a-ef31-403c-a14d-8e4673f7dd35 on host 25 at 2847.5s.
# Adversary: Processed EXPLOIT_VULN d0693a6a-ef31-403c-a14d-8e4673f7dd35 on host 25 at 2854.8s.
# Adversary: Start EXPLOIT_VULN 5d2b21bc-3d17-46d5-8b47-33117e113010 on host 25 at 2854.8s.
# Adversary: Processed EXPLOIT_VULN 5d2b21bc-3d17-46d5-8b47-33117e113010 on host 25 at 2856.7s.
# Adversary: Start EXPLOIT_VULN 9f3a9e44-6f99-4da5-998d-985bacf3b946 on host 25 at 2856.7s.
# Adversary: Processed EXPLOIT_VULN 9f3a9e44-6f99-4da5-998d-985bacf3b946 on host 25 at 2859.3s.
# Adversary: Start EXPLOIT_VULN d0693a6a-ef31-403c-a14d-8e4673f7dd35 on host 25 at 2859.3s.
# Adversary: Processed EXPLOIT_VULN d0693a6a-ef31-403c-a14d-8e4673f7dd35 on host 25 at 2863.1s.
# Adversary: Start EXPLOIT_VULN a24c123f-67cb-4d47-b49a-1c9a95782c1e on host 25 at 2863.1s.
# Adversary: Processed EXPLOIT_VULN a24c123f-67cb-4d47-b49a-1c9a95782c1e on host 25 at 2878.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 24564185-909b-484d-9ce7-9508e622b01a on host 25 at 2878.6s.
# Adversary: Processed EXPLOIT_VULN 24564185-909b-484d-9ce7-9508e622b01a on host 25 at 2887.2s.
# Adversary: Start BRUTE_FORCE at 2887.2s.
# Adversary: Processed BRUTE_FORCE at 2907.2s.
# Adversary: Start ENUM_HOST at 2907.2s.
# Adversary: Processed ENUM_HOST at 2912.2s.
# Adversary: Start SCAN_PORT at 2912.2s.
# MTD: CompleteTopologyShuffle finished in 120.4s at 2924.2s.
# MTD: Interrupted SCAN_PORT at 2924.2s!
# Adversary: Restarting with SCAN_HOST at 2944.4s!
# Adversary: Start SCAN_HOST at 2944.4s.
# Adversary: Processed SCAN_HOST at 2949.4s.
# Adversary: Start ENUM_HOST at 2949.4s.
# Adversary: Processed ENUM_HOST at 2954.4s.
# Adversary: Start SCAN_PORT at 2954.4s.
# Adversary: Processed SCAN_PORT at 2979.4s.
# Adversary: Start EXPLOIT_VULN aeac1bbe-e8de-46c4-8e16-799becfbe62c on host 25 at 2979.4s.
# Adversary: Processed EXPLOIT_VULN aeac1bbe-e8de-46c4-8e16-799becfbe62c on host 25 at 2986.4s.
# Adversary: Start EXPLOIT_VULN 6875e736-fd0e-44ab-95c0-8b053466b806 on host 25 at 2986.4s.
# Adversary: Processed EXPLOIT_VULN 6875e736-fd0e-44ab-95c0-8b053466b806 on host 25 at 2994.0s.
# Adversary: Start EXPLOIT_VULN 24564185-909b-484d-9ce7-9508e622b01a on host 25 at 2994.0s.

# %%
evaluation.get_network().draw()
plt.show()

# %%
evaluation.visualise_mtd_operation()

# %%
evaluation.visualise_attack_operation_group_by_host()

# %%
evaluation.visualise_attack_operation()
# Out:
# total compromised hosts:  15

# %%
evaluation.compromise_record_by_attack_action()
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 16   EXPLOIT_VULN   158.366203   168.604696  10.238493             0
# 25   EXPLOIT_VULN   242.320642   248.197067   5.876425            14
# 50   EXPLOIT_VULN   437.011767   440.467702   3.455935             9
# 77   EXPLOIT_VULN   711.119172   712.781787   1.662615            11
# 91   EXPLOIT_VULN   805.935364   812.628119   6.692755             5
# 139  EXPLOIT_VULN  1238.527105  1244.382497   5.855393            12
# 151  EXPLOIT_VULN  1355.058261  1359.989835   4.931574            20
# 176  EXPLOIT_VULN  1565.813502  1584.430665  18.617163            19
# 202  EXPLOIT_VULN  1785.527691  1806.864417  21.336726             6
# 233  EXPLOIT_VULN  2080.961559  2086.585075   5.623515            17
# 273  EXPLOIT_VULN  2465.312098  2477.210202  11.898104            10
# 292  EXPLOIT_VULN  2610.022005  2613.830457   3.808451            16
# 311  EXPLOIT_VULN  2779.453932  2787.949710   8.495779             7
# 318     SCAN_PORT  2817.949710  2842.949710  25.000000            15
# 333     SCAN_PORT  2947.726595  2972.726595  25.000000             8
#
#                         current_host_uuid compromise_host  \
# 16   dde18643-2108-43dd-a5b2-214cb4b466e7               0
# 25   611d33e1-472e-4c8a-bf8a-29ed8da11d20              14
# 50   2d3d3fdd-86d9-4f36-822c-cbbc4ec40a6c               9
# 77   1377a90c-5676-43f4-b533-321d0a4e8028              11
# 91   83f1a306-b790-457e-9c03-76dbd54e7fe6               5
# 139  699d8205-0950-4454-b8f1-e9acc0fcb0cf              12
# 151  6da997e2-bfa0-4314-885e-d3b4ac737629              20
# 176  93ad3fa5-0412-4994-b2c9-bcdde118e530              19
# 202  d166aa16-8403-4bf6-91b8-84409946f745               6
# 233  ccc741df-8d38-44de-83ab-47980d7eb6d3              17
# 273  2dd2d81b-c3d9-45e9-8011-4c430e832a03              10
# 292  f3b9d8ea-d7af-487f-ad01-8026630e0c60              16
# 311  95bc1f11-b8a0-42dd-90d9-2dd7f6563504               7
# 318  601c3042-5417-4464-bb36-24941aab1ca5              15
# 333  b0a3b2ec-342d-4c67-a78f-a32bdb777b9c               8
#
#                      compromise_host_uuid  current_host_attempt  \
# 16   dde18643-2108-43dd-a5b2-214cb4b466e7                     1
# 25   611d33e1-472e-4c8a-bf8a-29ed8da11d20                     1
# 50   2d3d3fdd-86d9-4f36-822c-cbbc4ec40a6c                     1
# 77   1377a90c-5676-43f4-b533-321d0a4e8028                     1
# 91   83f1a306-b790-457e-9c03-76dbd54e7fe6                     1
# 139  699d8205-0950-4454-b8f1-e9acc0fcb0cf                     1
# 151  6da997e2-bfa0-4314-885e-d3b4ac737629                     1
# 176  93ad3fa5-0412-4994-b2c9-bcdde118e530                     1
# 202  d166aa16-8403-4bf6-91b8-84409946f745                     1
# 233  ccc741df-8d38-44de-83ab-47980d7eb6d3                     1
# 273  2dd2d81b-c3d9-45e9-8011-4c430e832a03                     3
# 292  f3b9d8ea-d7af-487f-ad01-8026630e0c60                     1
# 311  95bc1f11-b8a0-42dd-90d9-2dd7f6563504                     3
# 318  601c3042-5417-4464-bb36-24941aab1ca5                     3
# 333  b0a3b2ec-342d-4c67-a78f-a32bdb777b9c                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 16                    11                             0
# 25                    17                             1
# 50                    35                             2
# 77                    57                             3
# 91                    66                             4
# 139                  104                             5
# 151                  109                             6
# 176                  126                             7
# 202                  145                             8
# 233                  163                             9
# 273                  187                            10
# 292                  199                            11
# 311                  208                            12
# 318                  209                            13
# 333                  211                            14
#
#                                  compromise_users interrupted_in  \
# 16       [Adele, Tanhya, Korney, Maurizia, Zarah]           None
# 25    [Aubine, Miriam, Cindee, Lenora, Kimberley]           None
# 50              [Allys, Jacklin, Yevette, Charin]           None
# 77                      [Koressa, Malina, Jo Ann]           None
# 91                      [Gertrudis, Pris, Marley]           None
# 139  [Virginia, Angelia, Bettina, Ellissa, Marjy]           None
# 151               [Jorie, Kipp, Martha, Nicholle]           None
# 176                                      [Sherye]           None
# 202                 [Trudie, Jeanna, Issy, Marlo]           None
# 233              [Lucienne, Robbyn, Kippy, Marty]           None
# 273                        [Sasha, Vonni, Lorene]           None
# 292   [Helaine, Jacki, Marsiella, Riki, Sherilyn]           None
# 311                [Lilas, Ainslee, Mitzi, Jenda]           None
# 318                                            []           None
# 333                               [Jeni, Ophelia]           None
#
#     interrupted_by   color curr_host_token
# 16            None  yellow               1
# 25            None  yellow               2
# 50            None  yellow               4
# 77            None  yellow               5
# 91            None  yellow               6
# 139           None  yellow               8
# 151           None  yellow               9
# 176           None  yellow              10
# 202           None  yellow              11
# 233           None  yellow              14
# 273           None  yellow               3
# 292           None  yellow              15
# 311           None  yellow              13
# 318           None   green              12
# 333           None   green              17

# %%
evaluation.compromise_record_by_attack_action('SCAN_PORT')
# Out:
#           name   start_time  finish_time  duration  current_host  \
# 318  SCAN_PORT  2817.949710  2842.949710      25.0            15
# 333  SCAN_PORT  2947.726595  2972.726595      25.0             8
#
#                         current_host_uuid compromise_host  \
# 318  601c3042-5417-4464-bb36-24941aab1ca5              15
# 333  b0a3b2ec-342d-4c67-a78f-a32bdb777b9c               8
#
#                      compromise_host_uuid  current_host_attempt  \
# 318  601c3042-5417-4464-bb36-24941aab1ca5                     3
# 333  b0a3b2ec-342d-4c67-a78f-a32bdb777b9c                     1
#
#      cumulative_attempts  cumulative_compromised_hosts compromise_users  \
# 318                  209                            13               []
# 333                  211                            14  [Jeni, Ophelia]
#
#     interrupted_in interrupted_by  color curr_host_token
# 318           None           None  green              12
# 333           None           None  green              17

# %%
evaluation.compromise_record_by_attack_action('EXPLOIT_VULN')
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 16   EXPLOIT_VULN   158.366203   168.604696  10.238493             0
# 25   EXPLOIT_VULN   242.320642   248.197067   5.876425            14
# 50   EXPLOIT_VULN   437.011767   440.467702   3.455935             9
# 77   EXPLOIT_VULN   711.119172   712.781787   1.662615            11
# 91   EXPLOIT_VULN   805.935364   812.628119   6.692755             5
# 139  EXPLOIT_VULN  1238.527105  1244.382497   5.855393            12
# 151  EXPLOIT_VULN  1355.058261  1359.989835   4.931574            20
# 176  EXPLOIT_VULN  1565.813502  1584.430665  18.617163            19
# 202  EXPLOIT_VULN  1785.527691  1806.864417  21.336726             6
# 233  EXPLOIT_VULN  2080.961559  2086.585075   5.623515            17
# 273  EXPLOIT_VULN  2465.312098  2477.210202  11.898104            10
# 292  EXPLOIT_VULN  2610.022005  2613.830457   3.808451            16
# 311  EXPLOIT_VULN  2779.453932  2787.949710   8.495779             7
#
#                         current_host_uuid compromise_host  \
# 16   dde18643-2108-43dd-a5b2-214cb4b466e7               0
# 25   611d33e1-472e-4c8a-bf8a-29ed8da11d20              14
# 50   2d3d3fdd-86d9-4f36-822c-cbbc4ec40a6c               9
# 77   1377a90c-5676-43f4-b533-321d0a4e8028              11
# 91   83f1a306-b790-457e-9c03-76dbd54e7fe6               5
# 139  699d8205-0950-4454-b8f1-e9acc0fcb0cf              12
# 151  6da997e2-bfa0-4314-885e-d3b4ac737629              20
# 176  93ad3fa5-0412-4994-b2c9-bcdde118e530              19
# 202  d166aa16-8403-4bf6-91b8-84409946f745               6
# 233  ccc741df-8d38-44de-83ab-47980d7eb6d3              17
# 273  2dd2d81b-c3d9-45e9-8011-4c430e832a03              10
# 292  f3b9d8ea-d7af-487f-ad01-8026630e0c60              16
# 311  95bc1f11-b8a0-42dd-90d9-2dd7f6563504               7
#
#                      compromise_host_uuid  current_host_attempt  \
# 16   dde18643-2108-43dd-a5b2-214cb4b466e7                     1
# 25   611d33e1-472e-4c8a-bf8a-29ed8da11d20                     1
# 50   2d3d3fdd-86d9-4f36-822c-cbbc4ec40a6c                     1
# 77   1377a90c-5676-43f4-b533-321d0a4e8028                     1
# 91   83f1a306-b790-457e-9c03-76dbd54e7fe6                     1
# 139  699d8205-0950-4454-b8f1-e9acc0fcb0cf                     1
# 151  6da997e2-bfa0-4314-885e-d3b4ac737629                     1
# 176  93ad3fa5-0412-4994-b2c9-bcdde118e530                     1
# 202  d166aa16-8403-4bf6-91b8-84409946f745                     1
# 233  ccc741df-8d38-44de-83ab-47980d7eb6d3                     1
# 273  2dd2d81b-c3d9-45e9-8011-4c430e832a03                     3
# 292  f3b9d8ea-d7af-487f-ad01-8026630e0c60                     1
# 311  95bc1f11-b8a0-42dd-90d9-2dd7f6563504                     3
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 16                    11                             0
# 25                    17                             1
# 50                    35                             2
# 77                    57                             3
# 91                    66                             4
# 139                  104                             5
# 151                  109                             6
# 176                  126                             7
# 202                  145                             8
# 233                  163                             9
# 273                  187                            10
# 292                  199                            11
# 311                  208                            12
#
#                                  compromise_users interrupted_in  \
# 16       [Adele, Tanhya, Korney, Maurizia, Zarah]           None
# 25    [Aubine, Miriam, Cindee, Lenora, Kimberley]           None
# 50              [Allys, Jacklin, Yevette, Charin]           None
# 77                      [Koressa, Malina, Jo Ann]           None
# 91                      [Gertrudis, Pris, Marley]           None
# 139  [Virginia, Angelia, Bettina, Ellissa, Marjy]           None
# 151               [Jorie, Kipp, Martha, Nicholle]           None
# 176                                      [Sherye]           None
# 202                 [Trudie, Jeanna, Issy, Marlo]           None
# 233              [Lucienne, Robbyn, Kippy, Marty]           None
# 273                        [Sasha, Vonni, Lorene]           None
# 292   [Helaine, Jacki, Marsiella, Riki, Sherilyn]           None
# 311                [Lilas, Ainslee, Mitzi, Jenda]           None
#
#     interrupted_by   color curr_host_token
# 16            None  yellow               1
# 25            None  yellow               2
# 50            None  yellow               4
# 77            None  yellow               5
# 91            None  yellow               6
# 139           None  yellow               8
# 151           None  yellow               9
# 176           None  yellow              10
# 202           None  yellow              11
# 233           None  yellow              14
# 273           None  yellow               3
# 292           None  yellow              15
# 311           None  yellow              13

# %%
evaluation.compromise_record_by_attack_action('BRUTE_FORCE')
# Out:
# Empty DataFrame
# Columns: [name, start_time, finish_time, duration, current_host, current_host_uuid, compromise_host, compromise_host_uuid, current_host_attempt, cumulative_attempts, cumulative_compromised_hosts, compromise_users, interrupted_in, interrupted_by, color, curr_host_token]
# Index: []

# %%
evaluation.evaluation_result_by_compromise_checkpoint()
# Out:
# [{'time_to_compromise': 1976.2929313125037,
#   'attack_success_rate': 0.4166666666666667,
#   'host_compromise_ratio': 0.1,
#   'mtd_execution_frequency': 0.005141689627543342}]

# %%
print(evaluation.get_network().get_mtd_stats().get_record())
# Out:
#                        name   start_time  finish_time    duration  executed_at
# 0               OSDiversity     0.000000    80.699861   80.699861  application
# 1                 IPShuffle   200.075912   310.126656  110.050745      network
# 2               OSDiversity   400.218076   480.823100   80.605024  application
# 3   CompleteTopologyShuffle   602.133505   722.304312  120.170807      network
# 4   CompleteTopologyShuffle   802.194014   922.395424  120.201410      network
# 5               OSDiversity  1002.484895  1082.733224   80.248329  application
# 6               OSDiversity  1202.650215  1282.696630   80.046415  application
# 7               OSDiversity  1403.077580  1483.146251   80.068671  application
# 8          ServiceDiversity  1603.800660  1674.634723   70.834063  application
# 9   CompleteTopologyShuffle  1804.002967  1924.192144  120.189177      network
# 10  CompleteTopologyShuffle  2004.257152  2124.600161  120.343009      network
# 11                IPShuffle  2205.944735  2317.198605  111.253870      network
# 12              OSDiversity  2406.343264  2486.801293   80.458029  application
# 13                IPShuffle  2606.475300  2717.041057  110.565758      network
# 14                IPShuffle  2807.139135  2917.328950  110.189815      network

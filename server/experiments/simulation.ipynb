# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging

logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])

# %%
evaluation = execute_simulation(start_time=0, finish_time=3000, mtd_interval=200, scheme='random', total_nodes=100)
# Out:
# Adversary: Start SCAN_HOST at 0.0s.
# MTD: CompleteTopologyShuffle triggered 0.0s
# MTD: CompleteTopologyShuffle deployed in the network at 0.0s.
# Adversary: Processed SCAN_HOST at 5.0s.
# Adversary: Start ENUM_HOST at 5.0s.
# Adversary: Processed ENUM_HOST at 10.0s.
# Adversary: Start SCAN_PORT at 10.0s.
# Adversary: Processed SCAN_PORT at 35.0s.
# Adversary: Start EXPLOIT_VULN 6af1e605-ad67-4427-bc2e-294840a0104d on host 0 at 35.0s.
# Adversary: Processed EXPLOIT_VULN 6af1e605-ad67-4427-bc2e-294840a0104d on host 0 at 37.1s.
# Adversary: Start EXPLOIT_VULN d2ff2411-ffd6-4b11-a160-ca0f857815b1 on host 0 at 37.1s.
# Adversary: Processed EXPLOIT_VULN d2ff2411-ffd6-4b11-a160-ca0f857815b1 on host 0 at 43.7s.
# Adversary: Start EXPLOIT_VULN 645ed271-dba0-46e6-b8df-2580d4f978a7 on host 0 at 43.7s.
# Adversary: Processed EXPLOIT_VULN 645ed271-dba0-46e6-b8df-2580d4f978a7 on host 0 at 49.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a63c2e2e-0db5-4c1f-887b-6c2bcdb36d49 on host 0 at 49.8s.
# Adversary: Processed EXPLOIT_VULN a63c2e2e-0db5-4c1f-887b-6c2bcdb36d49 on host 0 at 59.0s.
# Adversary: Start EXPLOIT_VULN 613f011c-668c-4e7e-b96f-4e67567aeda0 on host 0 at 59.0s.
# Adversary: Processed EXPLOIT_VULN 613f011c-668c-4e7e-b96f-4e67567aeda0 on host 0 at 63.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c2b447f5-5096-44ea-96b9-66d37a8c0e95 on host 0 at 63.1s.
# Adversary: Processed EXPLOIT_VULN c2b447f5-5096-44ea-96b9-66d37a8c0e95 on host 0 at 72.2s.
# Adversary: Host 0 has been compromised at 72.2s!
# Adversary: Start SCAN_NEIGHBOR at 72.2s.
# Adversary: Processed SCAN_NEIGHBOR at 77.2s.
# Adversary: Start ENUM_HOST at 77.2s.
# Adversary: Processed ENUM_HOST at 82.2s.
# Adversary: Start SCAN_PORT at 82.2s.
# Adversary: Processed SCAN_PORT at 107.2s.
# Adversary: Start EXPLOIT_VULN 26e47b10-8396-46dc-b4bc-328bed933193 on host 13 at 107.2s.
# Adversary: Processed EXPLOIT_VULN 26e47b10-8396-46dc-b4bc-328bed933193 on host 13 at 107.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a68e7040-9ab5-4353-bd60-04ab3b3ba2f1 on host 13 at 107.8s.
# Adversary: Processed EXPLOIT_VULN a68e7040-9ab5-4353-bd60-04ab3b3ba2f1 on host 13 at 116.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9d671535-4f38-4983-a42b-bd5440adb883 on host 13 at 116.9s.
# MTD: CompleteTopologyShuffle finished in 120.3s at 120.3s.
# MTD: Interrupted EXPLOIT_VULN at 120.3s!
# Adversary: Restarting with SCAN_HOST at 140.7s!
# Adversary: Start SCAN_HOST at 140.7s.
# Adversary: Processed SCAN_HOST at 145.7s.
# Adversary: Start ENUM_HOST at 145.7s.
# Adversary: Processed ENUM_HOST at 150.7s.
# Adversary: Start SCAN_PORT at 150.7s.
# Adversary: Processed SCAN_PORT at 175.7s.
# Adversary: Start EXPLOIT_VULN 9bf7404a-ee17-4a2a-98a7-ee55d1a1838a on host 13 at 175.7s.
# Adversary: Processed EXPLOIT_VULN 9bf7404a-ee17-4a2a-98a7-ee55d1a1838a on host 13 at 180.3s.
# Adversary: Start EXPLOIT_VULN 81c0dada-2332-44b9-835b-250366dd09af on host 13 at 180.3s.
# Adversary: Processed EXPLOIT_VULN 81c0dada-2332-44b9-835b-250366dd09af on host 13 at 194.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2cf0ce5a-d212-422a-a9b5-eda8b175ed0f on host 13 at 194.8s.
# MTD: IPShuffle triggered 200.1s
# MTD: IPShuffle deployed in the network at 200.1s.
# Adversary: Processed EXPLOIT_VULN 2cf0ce5a-d212-422a-a9b5-eda8b175ed0f on host 13 at 214.3s.
# Adversary: Start EXPLOIT_VULN 9d671535-4f38-4983-a42b-bd5440adb883 on host 13 at 214.3s.
# Adversary: Processed EXPLOIT_VULN 9d671535-4f38-4983-a42b-bd5440adb883 on host 13 at 224.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 56d7cd90-5574-4df3-9cc4-3a13cf072c5f on host 13 at 224.5s.
# Adversary: Processed EXPLOIT_VULN 56d7cd90-5574-4df3-9cc4-3a13cf072c5f on host 13 at 226.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c6796f89-0ae5-47a4-9430-5f783f180a81 on host 13 at 226.0s.
# Adversary: Processed EXPLOIT_VULN c6796f89-0ae5-47a4-9430-5f783f180a81 on host 13 at 231.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6056c1f7-a027-4e90-af29-4e8d3645df7c on host 13 at 231.1s.
# Adversary: Processed EXPLOIT_VULN 6056c1f7-a027-4e90-af29-4e8d3645df7c on host 13 at 243.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f13504c0-217f-42f5-99b7-42fe7545040c on host 13 at 243.7s.
# Adversary: Processed EXPLOIT_VULN f13504c0-217f-42f5-99b7-42fe7545040c on host 13 at 252.4s.
# Adversary: Start EXPLOIT_VULN b5515c7d-f40c-412e-979b-b73f4d06ba79 on host 13 at 252.4s.
# Adversary: Processed EXPLOIT_VULN b5515c7d-f40c-412e-979b-b73f4d06ba79 on host 13 at 255.3s.
# Adversary: Start EXPLOIT_VULN 72c8f9b4-695b-4498-aa8e-82c9c28f3ff7 on host 13 at 255.3s.
# Adversary: Processed EXPLOIT_VULN 72c8f9b4-695b-4498-aa8e-82c9c28f3ff7 on host 13 at 266.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 63567dbd-578e-48f5-be38-16a7d001646d on host 13 at 266.8s.
# Adversary: Processed EXPLOIT_VULN 63567dbd-578e-48f5-be38-16a7d001646d on host 13 at 274.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b8108c79-e500-4c12-bcb2-cc62e8d8d9a9 on host 13 at 274.1s.
# Adversary: Processed EXPLOIT_VULN b8108c79-e500-4c12-bcb2-cc62e8d8d9a9 on host 13 at 278.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3adc1c3a-a91e-428d-b0b0-51e77a3be5e7 on host 13 at 278.5s.
# Adversary: Processed EXPLOIT_VULN 3adc1c3a-a91e-428d-b0b0-51e77a3be5e7 on host 13 at 281.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 428974d1-e881-4e43-80fb-28f3ec0778f5 on host 13 at 281.6s.
# Adversary: Processed EXPLOIT_VULN 428974d1-e881-4e43-80fb-28f3ec0778f5 on host 13 at 281.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e816775b-ddcb-421b-8d11-9e8308b85c82 on host 13 at 281.8s.
# Adversary: Processed EXPLOIT_VULN e816775b-ddcb-421b-8d11-9e8308b85c82 on host 13 at 286.5s.
# Adversary: Start EXPLOIT_VULN 761d59ec-7f0f-4772-9f43-9222e000e30f on host 13 at 286.5s.
# Adversary: Processed EXPLOIT_VULN 761d59ec-7f0f-4772-9f43-9222e000e30f on host 13 at 288.9s.
# Adversary: Start EXPLOIT_VULN c214fc3b-5eb4-45ca-8078-9243702e4bc3 on host 13 at 288.9s.
# Adversary: Processed EXPLOIT_VULN c214fc3b-5eb4-45ca-8078-9243702e4bc3 on host 13 at 294.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 13 has been compromised at 294.2s!
# Adversary: Start SCAN_NEIGHBOR at 294.2s.
# Adversary: Processed SCAN_NEIGHBOR at 299.2s.
# Adversary: Start ENUM_HOST at 299.2s.
# Adversary: Processed ENUM_HOST at 304.2s.
# Adversary: Start SCAN_PORT at 304.2s.
# MTD: IPShuffle finished in 110.1s at 310.1s.
# MTD: Interrupted SCAN_PORT at 310.1s!
# Adversary: Restarting with SCAN_HOST at 330.2s!
# Adversary: Start SCAN_HOST at 330.2s.
# Adversary: Processed SCAN_HOST at 335.2s.
# Adversary: Start ENUM_HOST at 335.2s.
# Adversary: Processed ENUM_HOST at 340.2s.
# Adversary: Start SCAN_PORT at 340.2s.
# Adversary: Processed SCAN_PORT at 365.2s.
# Adversary: Start EXPLOIT_VULN c4942623-ba18-4dd4-8acd-8692ae11f2c9 on host 6 at 365.2s.
# Adversary: Processed EXPLOIT_VULN c4942623-ba18-4dd4-8acd-8692ae11f2c9 on host 6 at 366.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b47985d8-af32-4bed-a71f-5210c632e347 on host 6 at 366.0s.
# Adversary: Processed EXPLOIT_VULN b47985d8-af32-4bed-a71f-5210c632e347 on host 6 at 367.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 545f99fb-73fa-4246-8a47-1bb469a40eb6 on host 6 at 367.0s.
# Adversary: Processed EXPLOIT_VULN 545f99fb-73fa-4246-8a47-1bb469a40eb6 on host 6 at 367.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN b8fb4b45-5a69-42dc-a523-e615371ec58f on host 6 at 367.3s.
# Adversary: Processed EXPLOIT_VULN b8fb4b45-5a69-42dc-a523-e615371ec58f on host 6 at 369.4s.
# Adversary: Start EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 6 at 369.4s.
# Adversary: Processed EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 6 at 389.3s.
# Adversary: Start EXPLOIT_VULN 7beef9c3-7630-401e-b8e3-cf7ad79e33b4 on host 6 at 389.3s.
# Adversary: Processed EXPLOIT_VULN 7beef9c3-7630-401e-b8e3-cf7ad79e33b4 on host 6 at 390.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 390.9s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 399.2s.
# Adversary: Start EXPLOIT_VULN 1ab622f7-030d-4bcd-ad61-9536ed04d709 on host 6 at 399.2s.
# MTD: CompleteTopologyShuffle triggered 400.7s
# MTD: CompleteTopologyShuffle deployed in the network at 400.7s.
# Adversary: Processed EXPLOIT_VULN 1ab622f7-030d-4bcd-ad61-9536ed04d709 on host 6 at 407.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7beef9c3-7630-401e-b8e3-cf7ad79e33b4 on host 6 at 407.6s.
# Adversary: Processed EXPLOIT_VULN 7beef9c3-7630-401e-b8e3-cf7ad79e33b4 on host 6 at 409.6s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 409.6s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 417.9s.
# Adversary: Start EXPLOIT_VULN e5868159-9b4b-4b71-93fb-4678fcde0175 on host 6 at 417.9s.
# Adversary: Processed EXPLOIT_VULN e5868159-9b4b-4b71-93fb-4678fcde0175 on host 6 at 419.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 62a53803-1b99-43f6-ad60-b07b1476543e on host 6 at 419.9s.
# Adversary: Processed EXPLOIT_VULN 62a53803-1b99-43f6-ad60-b07b1476543e on host 6 at 421.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ffdc47e2-d9a9-4b05-ac1c-b703f51cd762 on host 6 at 421.8s.
# Adversary: Processed EXPLOIT_VULN ffdc47e2-d9a9-4b05-ac1c-b703f51cd762 on host 6 at 443.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start BRUTE_FORCE at 443.2s.
# Adversary: Processed BRUTE_FORCE at 463.2s.
# Adversary: Start ENUM_HOST at 463.2s.
# Adversary: Processed ENUM_HOST at 468.2s.
# Adversary: Start SCAN_PORT at 468.2s.
# Adversary: Processed SCAN_PORT at 493.2s.
# Adversary: Start EXPLOIT_VULN c9086497-49bc-45f9-b358-425477b4e3ff on host 14 at 493.2s.
# Adversary: Processed EXPLOIT_VULN c9086497-49bc-45f9-b358-425477b4e3ff on host 14 at 496.1s.
# Adversary: Start EXPLOIT_VULN 8a5562b4-c084-4c3d-a471-2756b1e74052 on host 14 at 496.1s.
# Adversary: Processed EXPLOIT_VULN 8a5562b4-c084-4c3d-a471-2756b1e74052 on host 14 at 500.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 14fdc026-5971-4100-9625-dd64c5929afd on host 14 at 500.3s.
# Adversary: Processed EXPLOIT_VULN 14fdc026-5971-4100-9625-dd64c5929afd on host 14 at 506.8s.
# Adversary: Start EXPLOIT_VULN e7369d9a-fa64-4a47-9532-b30ee7eb7017 on host 14 at 506.8s.
# Adversary: Processed EXPLOIT_VULN e7369d9a-fa64-4a47-9532-b30ee7eb7017 on host 14 at 513.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c8c1d165-0a43-43c7-9074-bb7f14f1f6da on host 14 at 513.7s.
# Adversary: Processed EXPLOIT_VULN c8c1d165-0a43-43c7-9074-bb7f14f1f6da on host 14 at 520.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 405f9ec0-5be1-46fc-a10b-ee864bd62163 on host 14 at 520.8s.
# MTD: CompleteTopologyShuffle finished in 121.4s at 522.1s.
# MTD: Interrupted EXPLOIT_VULN at 522.1s!
# Adversary: Restarting with SCAN_HOST at 542.2s!
# Adversary: Start SCAN_HOST at 542.2s.
# Adversary: Processed SCAN_HOST at 547.2s.
# Adversary: Start ENUM_HOST at 547.2s.
# Adversary: Processed ENUM_HOST at 552.2s.
# Adversary: Start SCAN_PORT at 552.2s.
# Adversary: Processed SCAN_PORT at 577.2s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 577.2s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 586.3s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 586.3s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 6 at 594.8s.
# Adversary: Start EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 6 at 594.8s.
# MTD: IPShuffle triggered 601.0s
# MTD: IPShuffle deployed in the network at 601.0s.
# Adversary: Processed EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 6 at 614.8s.
# Adversary: Start EXPLOIT_VULN c5f11ad8-6772-4f24-8776-3fc436397512 on host 6 at 614.8s.
# Adversary: Processed EXPLOIT_VULN c5f11ad8-6772-4f24-8776-3fc436397512 on host 6 at 618.7s.
# Adversary: Start EXPLOIT_VULN 124b8df9-c2ca-406c-b982-f2f7302bb7ac on host 6 at 618.7s.
# Adversary: Processed EXPLOIT_VULN 124b8df9-c2ca-406c-b982-f2f7302bb7ac on host 6 at 622.9s.
# Adversary: Start EXPLOIT_VULN 421fe26d-55e1-48d2-8559-9d9086593054 on host 6 at 622.9s.
# Adversary: Processed EXPLOIT_VULN 421fe26d-55e1-48d2-8559-9d9086593054 on host 6 at 627.1s.
# Adversary: Start EXPLOIT_VULN f74b9366-ea85-40fb-af21-5fbb89aabda1 on host 6 at 627.1s.
# Adversary: Processed EXPLOIT_VULN f74b9366-ea85-40fb-af21-5fbb89aabda1 on host 6 at 633.3s.
# Adversary: Start EXPLOIT_VULN aa192110-fda7-40e0-9eee-c4e256eeeedc on host 6 at 633.3s.
# Adversary: Processed EXPLOIT_VULN aa192110-fda7-40e0-9eee-c4e256eeeedc on host 6 at 636.3s.
# Adversary: Start EXPLOIT_VULN a7677f7c-906c-4f05-ad59-ef7e9e18958a on host 6 at 636.3s.
# Adversary: Processed EXPLOIT_VULN a7677f7c-906c-4f05-ad59-ef7e9e18958a on host 6 at 642.7s.
# Adversary: Host 6 has been compromised at 642.7s!
# Adversary: Start SCAN_NEIGHBOR at 642.7s.
# Adversary: Processed SCAN_NEIGHBOR at 647.7s.
# Adversary: Start ENUM_HOST at 647.7s.
# Adversary: Processed ENUM_HOST at 652.7s.
# Adversary: Start SCAN_PORT at 652.7s.
# Adversary: Processed SCAN_PORT at 677.7s.
# Adversary: Start EXPLOIT_VULN 2dbee180-0e84-46af-9748-63cf6abbac40 on host 18 at 677.7s.
# Adversary: Processed EXPLOIT_VULN 2dbee180-0e84-46af-9748-63cf6abbac40 on host 18 at 679.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5ebdbfd2-e01f-40c5-852e-15edbe445711 on host 18 at 679.1s.
# Adversary: Processed EXPLOIT_VULN 5ebdbfd2-e01f-40c5-852e-15edbe445711 on host 18 at 681.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f1c4fd1c-904f-4b66-8c45-7c8f9a35ae29 on host 18 at 681.7s.
# Adversary: Processed EXPLOIT_VULN f1c4fd1c-904f-4b66-8c45-7c8f9a35ae29 on host 18 at 689.3s.
# Adversary: Start EXPLOIT_VULN f7f56d3a-075a-485f-9f4a-45b586c2445b on host 18 at 689.3s.
# Adversary: Processed EXPLOIT_VULN f7f56d3a-075a-485f-9f4a-45b586c2445b on host 18 at 692.1s.
# Adversary: Start EXPLOIT_VULN 6c5f316a-4520-46dd-9426-f717f8a77c3d on host 18 at 692.1s.
# Adversary: Processed EXPLOIT_VULN 6c5f316a-4520-46dd-9426-f717f8a77c3d on host 18 at 698.6s.
# Adversary: Start EXPLOIT_VULN 436cbb79-b9cd-4f8c-b5f7-b2f9cce2e876 on host 18 at 698.6s.
# Adversary: Processed EXPLOIT_VULN 436cbb79-b9cd-4f8c-b5f7-b2f9cce2e876 on host 18 at 702.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 18 has been compromised at 702.1s!
# Adversary: Start SCAN_NEIGHBOR at 702.1s.
# Adversary: Processed SCAN_NEIGHBOR at 707.1s.
# Adversary: Start ENUM_HOST at 707.1s.
# MTD: IPShuffle finished in 110.1s at 711.1s.
# MTD: Interrupted ENUM_HOST at 711.1s!
# Adversary: Restarting with SCAN_HOST at 731.2s!
# Adversary: Start SCAN_HOST at 731.2s.
# Adversary: Processed SCAN_HOST at 736.2s.
# Adversary: Start ENUM_HOST at 736.2s.
# Adversary: Processed ENUM_HOST at 741.2s.
# Adversary: Start SCAN_PORT at 741.2s.
# Adversary: Processed SCAN_PORT at 766.2s.
# Adversary: Start EXPLOIT_VULN 78aa66ac-84c5-4f15-8c70-9a95490d9eac on host 11 at 766.2s.
# Adversary: Processed EXPLOIT_VULN 78aa66ac-84c5-4f15-8c70-9a95490d9eac on host 11 at 768.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 6c8628e7-f7e6-455a-9b02-475c0421d7a4 on host 11 at 768.9s.
# Adversary: Processed EXPLOIT_VULN 6c8628e7-f7e6-455a-9b02-475c0421d7a4 on host 11 at 769.8s.
# Adversary: Start EXPLOIT_VULN 8812527c-4413-4f4c-bb31-7b17898d9b6e on host 11 at 769.8s.
# Adversary: Processed EXPLOIT_VULN 8812527c-4413-4f4c-bb31-7b17898d9b6e on host 11 at 776.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 90aaa51d-c2f0-42ae-83f6-38d1ad8cff40 on host 11 at 776.1s.
# Adversary: Processed EXPLOIT_VULN 90aaa51d-c2f0-42ae-83f6-38d1ad8cff40 on host 11 at 785.3s.
# Adversary: Start EXPLOIT_VULN d6dfb9a9-00e1-4ae8-bc9b-e8b55f98e89a on host 11 at 785.3s.
# Adversary: Processed EXPLOIT_VULN d6dfb9a9-00e1-4ae8-bc9b-e8b55f98e89a on host 11 at 793.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5a9abaa-2fb6-403c-819d-115393b9da91 on host 11 at 793.8s.
# MTD: CompleteTopologyShuffle triggered 801.1s
# MTD: CompleteTopologyShuffle deployed in the network at 801.1s.
# Adversary: Processed EXPLOIT_VULN f5a9abaa-2fb6-403c-819d-115393b9da91 on host 11 at 803.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2cabf860-e58b-4611-8558-bd32f7006534 on host 11 at 803.8s.
# Adversary: Processed EXPLOIT_VULN 2cabf860-e58b-4611-8558-bd32f7006534 on host 11 at 806.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e50e6305-0551-4a19-b680-df3ca8ce2257 on host 11 at 806.4s.
# Adversary: Processed EXPLOIT_VULN e50e6305-0551-4a19-b680-df3ca8ce2257 on host 11 at 815.2s.
# Adversary: Start EXPLOIT_VULN 57f63b85-5e11-4ed8-b405-b0a2b01b246e on host 11 at 815.2s.
# Adversary: Processed EXPLOIT_VULN 57f63b85-5e11-4ed8-b405-b0a2b01b246e on host 11 at 822.0s.
# Adversary: Start EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 822.0s.
# Adversary: Processed EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 827.9s.
# Adversary: Start EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 827.9s.
# Adversary: Processed EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 833.4s.
# Adversary: Start EXPLOIT_VULN 6db32b6d-dfcf-4640-8bbc-7c6a7210f8c5 on host 11 at 833.4s.
# Adversary: Processed EXPLOIT_VULN 6db32b6d-dfcf-4640-8bbc-7c6a7210f8c5 on host 11 at 834.5s.
# Adversary: Start EXPLOIT_VULN a4cd50bb-c7f6-4647-b9a8-b1e8de32bfe7 on host 11 at 834.5s.
# Adversary: Processed EXPLOIT_VULN a4cd50bb-c7f6-4647-b9a8-b1e8de32bfe7 on host 11 at 840.4s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 11 at 840.4s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 11 at 861.2s.
# Adversary: Start EXPLOIT_VULN 8ef59013-de49-4967-8dad-fafc85b0e6c7 on host 11 at 861.2s.
# Adversary: Processed EXPLOIT_VULN 8ef59013-de49-4967-8dad-fafc85b0e6c7 on host 11 at 871.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start BRUTE_FORCE at 871.6s.
# Adversary: Processed BRUTE_FORCE at 891.6s.
# Adversary: Start ENUM_HOST at 891.6s.
# Adversary: Processed ENUM_HOST at 896.6s.
# Adversary: Start SCAN_PORT at 896.6s.
# MTD: CompleteTopologyShuffle finished in 120.1s at 921.2s.
# MTD: Interrupted SCAN_PORT at 921.2s!
# Adversary: Restarting with SCAN_HOST at 941.9s!
# Adversary: Start SCAN_HOST at 941.9s.
# Adversary: Processed SCAN_HOST at 946.9s.
# Adversary: Start ENUM_HOST at 946.9s.
# Adversary: Processed ENUM_HOST at 951.9s.
# Adversary: Start SCAN_PORT at 951.9s.
# Adversary: Processed SCAN_PORT at 976.9s.
# Adversary: Start EXPLOIT_VULN be14f69d-b3ea-4b98-9962-4fd29a4ea8e1 on host 9 at 976.9s.
# Adversary: Processed EXPLOIT_VULN be14f69d-b3ea-4b98-9962-4fd29a4ea8e1 on host 9 at 977.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5142e18-fdb4-4b26-aafb-19afebf2a29f on host 9 at 977.9s.
# Adversary: Processed EXPLOIT_VULN f5142e18-fdb4-4b26-aafb-19afebf2a29f on host 9 at 986.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 32459f0f-1ab4-478b-9d63-1f7438c282a8 on host 9 at 986.7s.
# Adversary: Processed EXPLOIT_VULN 32459f0f-1ab4-478b-9d63-1f7438c282a8 on host 9 at 989.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c98581ea-d947-4b3a-9866-0b2cc9e646a2 on host 9 at 989.3s.
# Adversary: Processed EXPLOIT_VULN c98581ea-d947-4b3a-9866-0b2cc9e646a2 on host 9 at 996.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8c7e8341-1e94-4d46-a484-c79d388909fe on host 9 at 996.9s.
# MTD: CompleteTopologyShuffle triggered 1001.7s
# MTD: CompleteTopologyShuffle deployed in the network at 1001.7s.
# Adversary: Processed EXPLOIT_VULN 8c7e8341-1e94-4d46-a484-c79d388909fe on host 9 at 1010.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN a2126af5-9bfe-40f3-b0f6-3fd85b190e3f on host 9 at 1010.0s.
# Adversary: Processed EXPLOIT_VULN a2126af5-9bfe-40f3-b0f6-3fd85b190e3f on host 9 at 1018.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN fbe2259d-a469-4485-a4fb-e5031a432440 on host 9 at 1018.8s.
# Adversary: Processed EXPLOIT_VULN fbe2259d-a469-4485-a4fb-e5031a432440 on host 9 at 1029.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 09cc8990-1175-48e2-8db1-56542642527c on host 9 at 1029.2s.
# Adversary: Processed EXPLOIT_VULN 09cc8990-1175-48e2-8db1-56542642527c on host 9 at 1036.8s.
# Adversary: Start EXPLOIT_VULN c29eae61-8c1a-4c3c-92c0-8989f7b04a6c on host 9 at 1036.8s.
# Adversary: Processed EXPLOIT_VULN c29eae61-8c1a-4c3c-92c0-8989f7b04a6c on host 9 at 1040.5s.
# Adversary: Start EXPLOIT_VULN be14f69d-b3ea-4b98-9962-4fd29a4ea8e1 on host 9 at 1040.5s.
# Adversary: Processed EXPLOIT_VULN be14f69d-b3ea-4b98-9962-4fd29a4ea8e1 on host 9 at 1040.8s.
# Adversary: Start EXPLOIT_VULN f5142e18-fdb4-4b26-aafb-19afebf2a29f on host 9 at 1040.8s.
# Adversary: Processed EXPLOIT_VULN f5142e18-fdb4-4b26-aafb-19afebf2a29f on host 9 at 1045.2s.
# Adversary: Host 9 has been compromised at 1045.2s!
# Adversary: Start SCAN_NEIGHBOR at 1045.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1050.2s.
# Adversary: Start ENUM_HOST at 1050.2s.
# Adversary: Processed ENUM_HOST at 1055.2s.
# Adversary: Start SCAN_PORT at 1055.2s.
# Adversary: Processed SCAN_PORT at 1080.2s.
# Adversary: Start EXPLOIT_VULN 91c147b5-7c32-4d76-9101-850dbc83ed0e on host 12 at 1080.2s.
# Adversary: Processed EXPLOIT_VULN 91c147b5-7c32-4d76-9101-850dbc83ed0e on host 12 at 1088.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 836f219b-4fa5-46c5-95aa-7ccb928174c6 on host 12 at 1088.6s.
# Adversary: Processed EXPLOIT_VULN 836f219b-4fa5-46c5-95aa-7ccb928174c6 on host 12 at 1098.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 23d6a952-c0d2-44a2-b20f-13f56fb50dfb on host 12 at 1098.5s.
# Adversary: Processed EXPLOIT_VULN 23d6a952-c0d2-44a2-b20f-13f56fb50dfb on host 12 at 1100.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1a3757f6-1385-4e8b-a4e8-d23696978f11 on host 12 at 1100.2s.
# Adversary: Processed EXPLOIT_VULN 1a3757f6-1385-4e8b-a4e8-d23696978f11 on host 12 at 1108.2s.
# Adversary: Start EXPLOIT_VULN 5c62cf8f-612e-439d-9ba5-3498bce4e977 on host 12 at 1108.2s.
# Adversary: Processed EXPLOIT_VULN 5c62cf8f-612e-439d-9ba5-3498bce4e977 on host 12 at 1113.9s.
# Adversary: Start EXPLOIT_VULN 124b8df9-c2ca-406c-b982-f2f7302bb7ac on host 12 at 1113.9s.
# Adversary: Processed EXPLOIT_VULN 124b8df9-c2ca-406c-b982-f2f7302bb7ac on host 12 at 1118.8s.
# Adversary: Start EXPLOIT_VULN 8b55eed0-3553-4100-b8e8-2eb757f74d4f on host 12 at 1118.8s.
# MTD: CompleteTopologyShuffle finished in 120.4s at 1122.1s.
# MTD: Interrupted EXPLOIT_VULN at 1122.1s!
# Adversary: Restarting with SCAN_HOST at 1142.5s!
# Adversary: Start SCAN_HOST at 1142.5s.
# Adversary: Processed SCAN_HOST at 1147.5s.
# Adversary: Start ENUM_HOST at 1147.5s.
# Adversary: Processed ENUM_HOST at 1152.5s.
# Adversary: Start SCAN_PORT at 1152.5s.
# Adversary: Processed SCAN_PORT at 1177.5s.
# Adversary: Start EXPLOIT_VULN 9e26b9ba-5ebc-4873-9b2c-54ace46a6de2 on host 23 at 1177.5s.
# Adversary: Processed EXPLOIT_VULN 9e26b9ba-5ebc-4873-9b2c-54ace46a6de2 on host 23 at 1177.7s.
# Adversary: Start EXPLOIT_VULN 5319130f-2ca3-4519-b698-fd79a8f171c3 on host 23 at 1177.7s.
# Adversary: Processed EXPLOIT_VULN 5319130f-2ca3-4519-b698-fd79a8f171c3 on host 23 at 1181.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN fb138aa2-c747-4666-9f97-90ff5fa6ee69 on host 23 at 1181.9s.
# Adversary: Processed EXPLOIT_VULN fb138aa2-c747-4666-9f97-90ff5fa6ee69 on host 23 at 1183.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2d0ce670-cc11-4855-af7f-0d24ead88881 on host 23 at 1183.9s.
# Adversary: Processed EXPLOIT_VULN 2d0ce670-cc11-4855-af7f-0d24ead88881 on host 23 at 1193.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 81c16d42-cdb2-4a83-948e-26f0ffa2655f on host 23 at 1193.8s.
# Adversary: Processed EXPLOIT_VULN 81c16d42-cdb2-4a83-948e-26f0ffa2655f on host 23 at 1200.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 3f0859e9-7318-4b8a-a58e-3011b0ccb310 on host 23 at 1200.3s.
# Adversary: Processed EXPLOIT_VULN 3f0859e9-7318-4b8a-a58e-3011b0ccb310 on host 23 at 1201.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 43eb7535-4e56-4664-a42e-877878246ab5 on host 23 at 1201.7s.
# MTD: OSDiversity triggered 1201.7s
# MTD: OSDiversity deployed in the network at 1201.7s.
# Adversary: Processed EXPLOIT_VULN 43eb7535-4e56-4664-a42e-877878246ab5 on host 23 at 1202.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN c78e199e-3c30-453c-9298-f31112c536c6 on host 23 at 1202.6s.
# Adversary: Processed EXPLOIT_VULN c78e199e-3c30-453c-9298-f31112c536c6 on host 23 at 1203.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5d86e09-6678-432a-b074-5716c5aa9150 on host 23 at 1203.8s.
# Adversary: Processed EXPLOIT_VULN f5d86e09-6678-432a-b074-5716c5aa9150 on host 23 at 1209.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1bf8c725-5a89-48e1-a7bb-dcd38e683c91 on host 23 at 1209.6s.
# Adversary: Processed EXPLOIT_VULN 1bf8c725-5a89-48e1-a7bb-dcd38e683c91 on host 23 at 1218.1s.
# Adversary: Start EXPLOIT_VULN 189657b0-0956-4193-8f57-8e6eeccca40e on host 23 at 1218.1s.
# Adversary: Processed EXPLOIT_VULN 189657b0-0956-4193-8f57-8e6eeccca40e on host 23 at 1219.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ea6590df-737b-4929-bc79-f3473633ead8 on host 23 at 1219.8s.
# Adversary: Processed EXPLOIT_VULN ea6590df-737b-4929-bc79-f3473633ead8 on host 23 at 1223.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4d2c12e5-aa8f-44c9-8c31-38f4e56ca149 on host 23 at 1223.5s.
# Adversary: Processed EXPLOIT_VULN 4d2c12e5-aa8f-44c9-8c31-38f4e56ca149 on host 23 at 1225.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 0be57501-de9e-44da-bb5b-eba449c0ad3b on host 23 at 1225.4s.
# Adversary: Processed EXPLOIT_VULN 0be57501-de9e-44da-bb5b-eba449c0ad3b on host 23 at 1228.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4c7a610d-1bd7-4eb9-9e21-cab67a0683d4 on host 23 at 1228.1s.
# Adversary: Processed EXPLOIT_VULN 4c7a610d-1bd7-4eb9-9e21-cab67a0683d4 on host 23 at 1229.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8b98726a-5209-47ba-b257-1d9c5a6b4f24 on host 23 at 1229.9s.
# Adversary: Processed EXPLOIT_VULN 8b98726a-5209-47ba-b257-1d9c5a6b4f24 on host 23 at 1230.7s.
# Adversary: Start EXPLOIT_VULN a4d3d630-89c4-4eea-a9ae-7aa9ef17c458 on host 23 at 1230.7s.
# Adversary: Processed EXPLOIT_VULN a4d3d630-89c4-4eea-a9ae-7aa9ef17c458 on host 23 at 1232.5s.
# Adversary: Start EXPLOIT_VULN d4f43b84-7e06-496d-8e81-f938a6f46c76 on host 23 at 1232.5s.
# Adversary: Processed EXPLOIT_VULN d4f43b84-7e06-496d-8e81-f938a6f46c76 on host 23 at 1235.4s.
# Adversary: Start EXPLOIT_VULN ef91048f-7c15-40cd-a143-dbee8d9151e5 on host 23 at 1235.4s.
# Adversary: Processed EXPLOIT_VULN ef91048f-7c15-40cd-a143-dbee8d9151e5 on host 23 at 1238.2s.
# Adversary: Start EXPLOIT_VULN ddcb6c2f-1ff4-4f49-89c0-1008dc11c350 on host 23 at 1238.2s.
# Adversary: Processed EXPLOIT_VULN ddcb6c2f-1ff4-4f49-89c0-1008dc11c350 on host 23 at 1242.3s.
# Adversary: Start EXPLOIT_VULN d6caacbd-7d13-428a-b51a-804f07c66420 on host 23 at 1242.3s.
# Adversary: Processed EXPLOIT_VULN d6caacbd-7d13-428a-b51a-804f07c66420 on host 23 at 1244.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cbc31a45-102d-4213-a125-aeccd38ec5fd on host 23 at 1244.1s.
# Adversary: Processed EXPLOIT_VULN cbc31a45-102d-4213-a125-aeccd38ec5fd on host 23 at 1248.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bf9a97bf-db49-4edf-b319-a8659663673e on host 23 at 1248.4s.
# Adversary: Processed EXPLOIT_VULN bf9a97bf-db49-4edf-b319-a8659663673e on host 23 at 1253.3s.
# Adversary: Start EXPLOIT_VULN 1a3757f6-1385-4e8b-a4e8-d23696978f11 on host 23 at 1253.3s.
# Adversary: Processed EXPLOIT_VULN 1a3757f6-1385-4e8b-a4e8-d23696978f11 on host 23 at 1261.4s.
# Adversary: Start EXPLOIT_VULN ab10d0af-86a2-4f24-b5c8-fe887b24da51 on host 23 at 1261.4s.
# Adversary: Processed EXPLOIT_VULN ab10d0af-86a2-4f24-b5c8-fe887b24da51 on host 23 at 1264.3s.
# Adversary: Host 23 has been compromised at 1264.3s!
# Adversary: Start SCAN_NEIGHBOR at 1264.3s.
# Adversary: Processed SCAN_NEIGHBOR at 1269.3s.
# Adversary: Start ENUM_HOST at 1269.3s.
# Adversary: Processed ENUM_HOST at 1274.3s.
# Adversary: Start ENUM_HOST at 1274.3s.
# Adversary: Processed ENUM_HOST at 1279.3s.
# Adversary: Start SCAN_PORT at 1279.3s.
# MTD: OSDiversity finished in 80.3s at 1282.0s.
# MTD: Interrupted SCAN_PORT at 1282.0s!
# Adversary: Restarting with SCAN_PORT at 1302.0s!
# Adversary: Start SCAN_PORT at 1302.0s.
# Adversary: Processed SCAN_PORT at 1327.0s.
# Adversary: Start EXPLOIT_VULN 67d1eaf6-0055-4275-9b22-8c0bbbab5ed1 on host 21 at 1327.0s.
# Adversary: Processed EXPLOIT_VULN 67d1eaf6-0055-4275-9b22-8c0bbbab5ed1 on host 21 at 1327.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8cc8c4d9-a2b7-452b-8292-37775d8027e1 on host 21 at 1327.2s.
# Adversary: Processed EXPLOIT_VULN 8cc8c4d9-a2b7-452b-8292-37775d8027e1 on host 21 at 1341.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f781e05d-4fc4-4118-aa63-c106c99bb4e2 on host 21 at 1341.8s.
# Adversary: Processed EXPLOIT_VULN f781e05d-4fc4-4118-aa63-c106c99bb4e2 on host 21 at 1348.5s.
# Adversary: Start EXPLOIT_VULN 2964dc45-fb58-4558-8262-51314f1020b0 on host 21 at 1348.5s.
# Adversary: Processed EXPLOIT_VULN 2964dc45-fb58-4558-8262-51314f1020b0 on host 21 at 1357.6s.
# Adversary: Start EXPLOIT_VULN b7988de0-2794-4161-a3d9-019c88386cc2 on host 21 at 1357.6s.
# Adversary: Processed EXPLOIT_VULN b7988de0-2794-4161-a3d9-019c88386cc2 on host 21 at 1366.1s.
# Adversary: Start EXPLOIT_VULN 941157b4-fa86-47b1-a870-150cb00ae74c on host 21 at 1366.1s.
# Adversary: Processed EXPLOIT_VULN 941157b4-fa86-47b1-a870-150cb00ae74c on host 21 at 1383.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 8a43083d-5a91-4e6c-8e1b-946106a363d8 on host 21 at 1383.8s.
# Adversary: Processed EXPLOIT_VULN 8a43083d-5a91-4e6c-8e1b-946106a363d8 on host 21 at 1398.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 21 has been compromised at 1398.3s!
# Adversary: Start SCAN_NEIGHBOR at 1398.3s.
# MTD: CompleteTopologyShuffle triggered 1402.0s
# MTD: CompleteTopologyShuffle deployed in the network at 1402.0s.
# Adversary: Processed SCAN_NEIGHBOR at 1403.3s.
# Adversary: Start ENUM_HOST at 1403.3s.
# Adversary: Processed ENUM_HOST at 1408.3s.
# Adversary: Start SCAN_PORT at 1408.3s.
# Adversary: Processed SCAN_PORT at 1433.3s.
# Adversary: Start EXPLOIT_VULN 6c8628e7-f7e6-455a-9b02-475c0421d7a4 on host 11 at 1433.3s.
# Adversary: Processed EXPLOIT_VULN 6c8628e7-f7e6-455a-9b02-475c0421d7a4 on host 11 at 1434.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 90aaa51d-c2f0-42ae-83f6-38d1ad8cff40 on host 11 at 1434.6s.
# Adversary: Processed EXPLOIT_VULN 90aaa51d-c2f0-42ae-83f6-38d1ad8cff40 on host 11 at 1444.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e50e6305-0551-4a19-b680-df3ca8ce2257 on host 11 at 1444.1s.
# Adversary: Processed EXPLOIT_VULN e50e6305-0551-4a19-b680-df3ca8ce2257 on host 11 at 1453.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 1453.1s.
# Adversary: Processed EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 1458.3s.
# Adversary: Start EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 1458.3s.
# Adversary: Processed EXPLOIT_VULN 169bdf3d-96b5-4691-b205-e53093c4803a on host 11 at 1462.3s.
# Adversary: Start EXPLOIT_VULN a4cd50bb-c7f6-4647-b9a8-b1e8de32bfe7 on host 11 at 1462.3s.
# Adversary: Processed EXPLOIT_VULN a4cd50bb-c7f6-4647-b9a8-b1e8de32bfe7 on host 11 at 1468.3s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 11 at 1468.3s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 11 at 1488.9s.
# Adversary: Host 11 has been compromised at 1488.9s!
# Adversary: Start SCAN_NEIGHBOR at 1488.9s.
# Adversary: Processed SCAN_NEIGHBOR at 1493.9s.
# Adversary: Start ENUM_HOST at 1493.9s.
# Adversary: Processed ENUM_HOST at 1498.9s.
# Adversary: Start ENUM_HOST at 1498.9s.
# Adversary: Processed ENUM_HOST at 1503.9s.
# Adversary: Start ENUM_HOST at 1503.9s.
# Adversary: Processed ENUM_HOST at 1508.9s.
# Adversary: Start SCAN_PORT at 1508.9s.
# MTD: CompleteTopologyShuffle finished in 120.5s at 1522.5s.
# MTD: Interrupted SCAN_PORT at 1522.5s!
# Adversary: Restarting with SCAN_HOST at 1542.8s!
# Adversary: Start SCAN_HOST at 1542.8s.
# Adversary: Processed SCAN_HOST at 1547.8s.
# Adversary: Start ENUM_HOST at 1547.8s.
# Adversary: Processed ENUM_HOST at 1552.8s.
# Adversary: Start SCAN_PORT at 1552.8s.
# Adversary: Processed SCAN_PORT at 1577.8s.
# Adversary: Host 5 has been compromised at 1577.8s!
# Adversary: Start SCAN_NEIGHBOR at 1577.8s.
# Adversary: Processed SCAN_NEIGHBOR at 1582.8s.
# Adversary: Start ENUM_HOST at 1582.8s.
# Adversary: Processed ENUM_HOST at 1587.8s.
# Adversary: Start ENUM_HOST at 1587.8s.
# Adversary: Processed ENUM_HOST at 1592.8s.
# Adversary: Start ENUM_HOST at 1592.8s.
# Adversary: Processed ENUM_HOST at 1597.8s.
# Adversary: Start ENUM_HOST at 1597.8s.
# MTD: OSDiversity triggered 1602.2s
# MTD: OSDiversity deployed in the network at 1602.2s.
# Adversary: Processed ENUM_HOST at 1602.8s.
# Adversary: Start ENUM_HOST at 1602.8s.
# Adversary: Processed ENUM_HOST at 1607.8s.
# Adversary: Start ENUM_HOST at 1607.8s.
# Adversary: Processed ENUM_HOST at 1612.8s.
# Adversary: Start ENUM_HOST at 1612.8s.
# Adversary: Processed ENUM_HOST at 1617.8s.
# Adversary: Start SCAN_PORT at 1617.8s.
# Adversary: Processed SCAN_PORT at 1642.8s.
# Adversary: Host 24 has been compromised at 1642.8s!
# Adversary: Start SCAN_NEIGHBOR at 1642.8s.
# Adversary: Processed SCAN_NEIGHBOR at 1647.8s.
# Adversary: Start ENUM_HOST at 1647.8s.
# Adversary: Processed ENUM_HOST at 1652.8s.
# Adversary: Start ENUM_HOST at 1652.8s.
# Adversary: Processed ENUM_HOST at 1657.8s.
# Adversary: Start ENUM_HOST at 1657.8s.
# Adversary: Processed ENUM_HOST at 1662.8s.
# Adversary: Start ENUM_HOST at 1662.8s.
# Adversary: Processed ENUM_HOST at 1667.8s.
# Adversary: Start ENUM_HOST at 1667.8s.
# Adversary: Processed ENUM_HOST at 1672.8s.
# Adversary: Start SCAN_PORT at 1672.8s.
# MTD: OSDiversity finished in 80.9s at 1683.1s.
# MTD: Interrupted SCAN_PORT at 1683.1s!
# Adversary: Restarting with SCAN_PORT at 1703.2s!
# Adversary: Start SCAN_PORT at 1703.2s.
# Adversary: Processed SCAN_PORT at 1728.2s.
# Adversary: Host 28 has been compromised at 1728.2s!
# Adversary: Start SCAN_NEIGHBOR at 1728.2s.
# Adversary: Processed SCAN_NEIGHBOR at 1733.2s.
# Adversary: Start ENUM_HOST at 1733.2s.
# Adversary: Processed ENUM_HOST at 1738.2s.
# Adversary: Start SCAN_PORT at 1738.2s.
# Adversary: Processed SCAN_PORT at 1763.2s.
# Adversary: Start EXPLOIT_VULN 8b55eed0-3553-4100-b8e8-2eb757f74d4f on host 12 at 1763.2s.
# Adversary: Processed EXPLOIT_VULN 8b55eed0-3553-4100-b8e8-2eb757f74d4f on host 12 at 1769.9s.
# Adversary: Start EXPLOIT_VULN 14fdc026-5971-4100-9625-dd64c5929afd on host 12 at 1769.9s.
# Adversary: Processed EXPLOIT_VULN 14fdc026-5971-4100-9625-dd64c5929afd on host 12 at 1776.0s.
# Adversary: Start EXPLOIT_VULN fef7d764-a5f3-4c51-9d98-9a5f49219518 on host 12 at 1776.0s.
# Adversary: Processed EXPLOIT_VULN fef7d764-a5f3-4c51-9d98-9a5f49219518 on host 12 at 1779.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 12 at 1779.0s.
# Adversary: Processed EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 12 at 1790.0s.
# Adversary: Start EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 12 at 1790.0s.
# Adversary: Processed EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 12 at 1798.0s.
# Adversary: Start EXPLOIT_VULN 9bf7404a-ee17-4a2a-98a7-ee55d1a1838a on host 12 at 1798.0s.
# Adversary: Processed EXPLOIT_VULN 9bf7404a-ee17-4a2a-98a7-ee55d1a1838a on host 12 at 1799.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2cf0ce5a-d212-422a-a9b5-eda8b175ed0f on host 12 at 1799.8s.
# MTD: ServiceDiversity triggered 1802.2s
# MTD: ServiceDiversity deployed in the network at 1802.2s.
# Adversary: Processed EXPLOIT_VULN 2cf0ce5a-d212-422a-a9b5-eda8b175ed0f on host 12 at 1807.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 12 has been compromised at 1807.7s!
# Adversary: Start SCAN_NEIGHBOR at 1807.7s.
# Adversary: Processed SCAN_NEIGHBOR at 1812.7s.
# Adversary: Start ENUM_HOST at 1812.7s.
# Adversary: Processed ENUM_HOST at 1817.7s.
# Adversary: Start SCAN_PORT at 1817.7s.
# Adversary: Processed SCAN_PORT at 1842.7s.
# Adversary: Start EXPLOIT_VULN b5a6a0a0-50b9-45fd-b689-c2cc000dce1a on host 15 at 1842.7s.
# Adversary: Processed EXPLOIT_VULN b5a6a0a0-50b9-45fd-b689-c2cc000dce1a on host 15 at 1843.7s.
# Adversary: Start EXPLOIT_VULN 405f9ec0-5be1-46fc-a10b-ee864bd62163 on host 15 at 1843.7s.
# Adversary: Processed EXPLOIT_VULN 405f9ec0-5be1-46fc-a10b-ee864bd62163 on host 15 at 1848.0s.
# Adversary: Start EXPLOIT_VULN 7fd9be11-4ee2-4729-9696-c3e09e3a0b86 on host 15 at 1848.0s.
# Adversary: Processed EXPLOIT_VULN 7fd9be11-4ee2-4729-9696-c3e09e3a0b86 on host 15 at 1854.1s.
# Adversary: Start EXPLOIT_VULN aa321f99-8885-4826-a1de-9d5258aa00f6 on host 15 at 1854.1s.
# Adversary: Processed EXPLOIT_VULN aa321f99-8885-4826-a1de-9d5258aa00f6 on host 15 at 1863.6s.
# Adversary: Start EXPLOIT_VULN f1c4fd1c-904f-4b66-8c45-7c8f9a35ae29 on host 15 at 1863.6s.
# MTD: ServiceDiversity finished in 71.4s at 1873.6s.
# MTD: Interrupted EXPLOIT_VULN at 1873.6s!
# Adversary: Restarting with SCAN_PORT at 1893.9s!
# Adversary: Start SCAN_PORT at 1893.9s.
# Adversary: Processed SCAN_PORT at 1918.9s.
# Adversary: Start EXPLOIT_VULN 405f9ec0-5be1-46fc-a10b-ee864bd62163 on host 15 at 1918.9s.
# Adversary: Processed EXPLOIT_VULN 405f9ec0-5be1-46fc-a10b-ee864bd62163 on host 15 at 1922.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7fd9be11-4ee2-4729-9696-c3e09e3a0b86 on host 15 at 1922.8s.
# Adversary: Processed EXPLOIT_VULN 7fd9be11-4ee2-4729-9696-c3e09e3a0b86 on host 15 at 1930.0s.
# Adversary: Start EXPLOIT_VULN aa321f99-8885-4826-a1de-9d5258aa00f6 on host 15 at 1930.0s.
# Adversary: Processed EXPLOIT_VULN aa321f99-8885-4826-a1de-9d5258aa00f6 on host 15 at 1939.3s.
# Adversary: Start EXPLOIT_VULN f1c4fd1c-904f-4b66-8c45-7c8f9a35ae29 on host 15 at 1939.3s.
# Adversary: Processed EXPLOIT_VULN f1c4fd1c-904f-4b66-8c45-7c8f9a35ae29 on host 15 at 1960.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 37faceeb-6d8b-424e-a366-090ed5c9e8f6 on host 15 at 1960.7s.
# Adversary: Processed EXPLOIT_VULN 37faceeb-6d8b-424e-a366-090ed5c9e8f6 on host 15 at 1966.6s.
# Adversary: Start EXPLOIT_VULN 9994eb53-f61e-4d41-b4be-66440a488bde on host 15 at 1966.6s.
# Adversary: Processed EXPLOIT_VULN 9994eb53-f61e-4d41-b4be-66440a488bde on host 15 at 1974.2s.
# Adversary: Start EXPLOIT_VULN 256c7fbd-7b04-4393-98a0-7c53262a6a67 on host 15 at 1974.2s.
# Adversary: Processed EXPLOIT_VULN 256c7fbd-7b04-4393-98a0-7c53262a6a67 on host 15 at 1981.8s.
# Adversary: Start BRUTE_FORCE at 1981.8s.
# Adversary: Processed BRUTE_FORCE at 2001.8s.
# Adversary: Start ENUM_HOST at 2001.8s.
# MTD: OSDiversity triggered 2002.5s
# MTD: OSDiversity deployed in the network at 2002.5s.
# Adversary: Processed ENUM_HOST at 2006.8s.
# Adversary: Start SCAN_PORT at 2006.8s.
# Adversary: Processed SCAN_PORT at 2031.8s.
# Adversary: Start EXPLOIT_VULN a0ea62d6-2546-4ba3-88c5-1499957a07b4 on host 22 at 2031.8s.
# Adversary: Processed EXPLOIT_VULN a0ea62d6-2546-4ba3-88c5-1499957a07b4 on host 22 at 2033.0s.
# Adversary: Start EXPLOIT_VULN d315d987-5a20-4ba3-8fbc-0fef809689ec on host 22 at 2033.0s.
# Adversary: Processed EXPLOIT_VULN d315d987-5a20-4ba3-8fbc-0fef809689ec on host 22 at 2036.5s.
# Adversary: Start EXPLOIT_VULN a895b37c-ba58-46b0-916d-84b2037e4e51 on host 22 at 2036.5s.
# Adversary: Processed EXPLOIT_VULN a895b37c-ba58-46b0-916d-84b2037e4e51 on host 22 at 2042.7s.
# Adversary: Start EXPLOIT_VULN 3d4f9f2d-0ee1-4923-adb0-e98879415e3f on host 22 at 2042.7s.
# Adversary: Processed EXPLOIT_VULN 3d4f9f2d-0ee1-4923-adb0-e98879415e3f on host 22 at 2051.5s.
# Adversary: Start EXPLOIT_VULN 188c513a-0553-46cf-ace0-b12ae0f33433 on host 22 at 2051.5s.
# Adversary: Processed EXPLOIT_VULN 188c513a-0553-46cf-ace0-b12ae0f33433 on host 22 at 2053.1s.
# Adversary: Start EXPLOIT_VULN 9ce836c4-78de-4442-834e-57a90fcd7868 on host 22 at 2053.1s.
# Adversary: Processed EXPLOIT_VULN 9ce836c4-78de-4442-834e-57a90fcd7868 on host 22 at 2055.4s.
# Adversary: Start EXPLOIT_VULN 21951909-bc3e-4171-aeb3-29110fdf1a83 on host 22 at 2055.4s.
# Adversary: Processed EXPLOIT_VULN 21951909-bc3e-4171-aeb3-29110fdf1a83 on host 22 at 2061.6s.
# Adversary: Start EXPLOIT_VULN 4ce631cf-7009-45e3-91b2-6369bdfb386a on host 22 at 2061.6s.
# Adversary: Processed EXPLOIT_VULN 4ce631cf-7009-45e3-91b2-6369bdfb386a on host 22 at 2071.3s.
# Adversary: Host 22 has been compromised at 2071.3s!
# Adversary: Start SCAN_NEIGHBOR at 2071.3s.
# Adversary: Processed SCAN_NEIGHBOR at 2076.3s.
# Adversary: Start ENUM_HOST at 2076.3s.
# Adversary: Processed ENUM_HOST at 2081.3s.
# Adversary: Start ENUM_HOST at 2081.3s.
# MTD: OSDiversity finished in 80.9s at 2083.4s.
# Adversary: Processed ENUM_HOST at 2086.3s.
# Adversary: Start ENUM_HOST at 2086.3s.
# Adversary: Processed ENUM_HOST at 2091.3s.
# Adversary: Start ENUM_HOST at 2091.3s.
# Adversary: Processed ENUM_HOST at 2096.3s.
# Adversary: Start ENUM_HOST at 2096.3s.
# Adversary: Processed ENUM_HOST at 2101.3s.
# Adversary: Start ENUM_HOST at 2101.3s.
# Adversary: Processed ENUM_HOST at 2106.3s.
# Adversary: Start SCAN_PORT at 2106.3s.
# Adversary: Processed SCAN_PORT at 2131.3s.
# Adversary: Start EXPLOIT_VULN e7897e8d-d197-4a50-a1d3-eb216766e552 on host 7 at 2131.3s.
# Adversary: Processed EXPLOIT_VULN e7897e8d-d197-4a50-a1d3-eb216766e552 on host 7 at 2132.3s.
# Adversary: Start EXPLOIT_VULN 243554d2-6508-4ba2-9a37-23bee28818c2 on host 7 at 2132.3s.
# Adversary: Processed EXPLOIT_VULN 243554d2-6508-4ba2-9a37-23bee28818c2 on host 7 at 2134.8s.
# Adversary: Start EXPLOIT_VULN 44791898-87f2-4833-88e1-9366d6fed9c6 on host 7 at 2134.8s.
# Adversary: Processed EXPLOIT_VULN 44791898-87f2-4833-88e1-9366d6fed9c6 on host 7 at 2144.7s.
# Adversary: Start EXPLOIT_VULN e1646b66-0f8c-4e86-8262-14dde413496e on host 7 at 2144.7s.
# Adversary: Processed EXPLOIT_VULN e1646b66-0f8c-4e86-8262-14dde413496e on host 7 at 2146.7s.
# Adversary: Start EXPLOIT_VULN 282a8189-b404-402d-aa1c-f4249c33d9ff on host 7 at 2146.7s.
# Adversary: Processed EXPLOIT_VULN 282a8189-b404-402d-aa1c-f4249c33d9ff on host 7 at 2151.4s.
# Adversary: Start EXPLOIT_VULN 0a377091-d09f-4ed1-b84d-65f60157fb43 on host 7 at 2151.4s.
# Adversary: Processed EXPLOIT_VULN 0a377091-d09f-4ed1-b84d-65f60157fb43 on host 7 at 2154.5s.
# Adversary: Start EXPLOIT_VULN 17941e50-3279-4475-a754-40f4a1f86509 on host 7 at 2154.5s.
# Adversary: Processed EXPLOIT_VULN 17941e50-3279-4475-a754-40f4a1f86509 on host 7 at 2168.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN ff0e26c9-988f-4242-b427-29040b43ad0a on host 7 at 2168.0s.
# Adversary: Processed EXPLOIT_VULN ff0e26c9-988f-4242-b427-29040b43ad0a on host 7 at 2174.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 7 at 2174.2s.
# Adversary: Processed EXPLOIT_VULN bd66258b-7066-4145-b49b-0f1039e1716d on host 7 at 2182.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 096f09c7-158d-4b70-97ee-1deda36b1f5e on host 7 at 2182.3s.
# Adversary: Processed EXPLOIT_VULN 096f09c7-158d-4b70-97ee-1deda36b1f5e on host 7 at 2186.8s.
# Adversary: Start EXPLOIT_VULN 27db65a0-f54b-4c9d-88a9-25af48efa409 on host 7 at 2186.8s.
# Adversary: Processed EXPLOIT_VULN 27db65a0-f54b-4c9d-88a9-25af48efa409 on host 7 at 2196.6s.
# Adversary: Start EXPLOIT_VULN 82657d10-1215-4057-8f43-11dbd7b0d36a on host 7 at 2196.6s.
# MTD: CompleteTopologyShuffle triggered 2203.0s
# MTD: CompleteTopologyShuffle deployed in the network at 2203.0s.
# Adversary: Processed EXPLOIT_VULN 82657d10-1215-4057-8f43-11dbd7b0d36a on host 7 at 2205.4s.
# Adversary: Host 7 has been compromised at 2205.4s!
# Adversary: Start SCAN_NEIGHBOR at 2205.4s.
# Adversary: Processed SCAN_NEIGHBOR at 2210.4s.
# Adversary: Start ENUM_HOST at 2210.4s.
# Adversary: Processed ENUM_HOST at 2215.4s.
# Adversary: Start ENUM_HOST at 2215.4s.
# Adversary: Processed ENUM_HOST at 2220.4s.
# Adversary: Start ENUM_HOST at 2220.4s.
# Adversary: Processed ENUM_HOST at 2225.4s.
# Adversary: Start ENUM_HOST at 2225.4s.
# Adversary: Processed ENUM_HOST at 2230.4s.
# Adversary: Start ENUM_HOST at 2230.4s.
# Adversary: Processed ENUM_HOST at 2235.4s.
# Adversary: Start ENUM_HOST at 2235.4s.
# Adversary: Processed ENUM_HOST at 2240.4s.
# Adversary: Start SCAN_PORT at 2240.4s.
# Adversary: Processed SCAN_PORT at 2265.4s.
# Adversary: Start EXPLOIT_VULN 86c6660e-4ea3-42b6-82b6-8744b616e721 on host 20 at 2265.4s.
# Adversary: Processed EXPLOIT_VULN 86c6660e-4ea3-42b6-82b6-8744b616e721 on host 20 at 2267.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2eae8188-1f83-4b7d-aa8d-194231dbe941 on host 20 at 2267.8s.
# Adversary: Processed EXPLOIT_VULN 2eae8188-1f83-4b7d-aa8d-194231dbe941 on host 20 at 2277.0s.
# Adversary: Start EXPLOIT_VULN 0532e784-9be4-4a74-a90f-e0b24f737ef5 on host 20 at 2277.0s.
# Adversary: Processed EXPLOIT_VULN 0532e784-9be4-4a74-a90f-e0b24f737ef5 on host 20 at 2285.5s.
# Adversary: Start EXPLOIT_VULN 4a5bb554-931b-4bdf-80da-165d62a0484b on host 20 at 2285.5s.
# Adversary: Processed EXPLOIT_VULN 4a5bb554-931b-4bdf-80da-165d62a0484b on host 20 at 2286.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 86c6660e-4ea3-42b6-82b6-8744b616e721 on host 20 at 2286.8s.
# Adversary: Processed EXPLOIT_VULN 86c6660e-4ea3-42b6-82b6-8744b616e721 on host 20 at 2288.1s.
# Adversary: Start EXPLOIT_VULN 2eae8188-1f83-4b7d-aa8d-194231dbe941 on host 20 at 2288.1s.
# Adversary: Processed EXPLOIT_VULN 2eae8188-1f83-4b7d-aa8d-194231dbe941 on host 20 at 2298.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4a5bb554-931b-4bdf-80da-165d62a0484b on host 20 at 2298.5s.
# Adversary: Processed EXPLOIT_VULN 4a5bb554-931b-4bdf-80da-165d62a0484b on host 20 at 2299.4s.
# Adversary: Start EXPLOIT_VULN 72112d2d-e5fc-4c88-820a-45c9ce51b151 on host 20 at 2299.4s.
# Adversary: Processed EXPLOIT_VULN 72112d2d-e5fc-4c88-820a-45c9ce51b151 on host 20 at 2301.2s.
# Adversary: Start EXPLOIT_VULN 347e0c03-6d76-4801-bf6b-c22dad35dc45 on host 20 at 2301.2s.
# Adversary: Processed EXPLOIT_VULN 347e0c03-6d76-4801-bf6b-c22dad35dc45 on host 20 at 2307.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e8ed3075-dbac-4cc0-b261-bdb49ef0d637 on host 20 at 2307.0s.
# Adversary: Processed EXPLOIT_VULN e8ed3075-dbac-4cc0-b261-bdb49ef0d637 on host 20 at 2310.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN e0763a5a-87f8-45da-af6a-d99708350b4d on host 20 at 2310.1s.
# Adversary: Processed EXPLOIT_VULN e0763a5a-87f8-45da-af6a-d99708350b4d on host 20 at 2312.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 7aa5a88c-8bac-4f5c-a9e3-3ddd4f08bd85 on host 20 at 2312.9s.
# Adversary: Processed EXPLOIT_VULN 7aa5a88c-8bac-4f5c-a9e3-3ddd4f08bd85 on host 20 at 2318.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9542c005-56ac-43ca-bd64-0bcba82a3ad5 on host 20 at 2318.8s.
# MTD: CompleteTopologyShuffle finished in 120.8s at 2323.8s.
# MTD: Interrupted EXPLOIT_VULN at 2323.8s!
# Adversary: Restarting with SCAN_HOST at 2344.6s!
# Adversary: Start SCAN_HOST at 2344.6s.
# Adversary: Processed SCAN_HOST at 2349.6s.
# Adversary: Start ENUM_HOST at 2349.6s.
# Adversary: Processed ENUM_HOST at 2354.6s.
# Adversary: Start SCAN_PORT at 2354.6s.
# Adversary: Processed SCAN_PORT at 2379.6s.
# Adversary: Start EXPLOIT_VULN b2df0fcd-124e-44f8-a9b2-3944dabadd99 on host 25 at 2379.6s.
# Adversary: Processed EXPLOIT_VULN b2df0fcd-124e-44f8-a9b2-3944dabadd99 on host 25 at 2380.3s.
# Adversary: Start EXPLOIT_VULN 913c73f5-ba49-44d3-a0a5-16fa9024e04b on host 25 at 2380.3s.
# Adversary: Processed EXPLOIT_VULN 913c73f5-ba49-44d3-a0a5-16fa9024e04b on host 25 at 2381.5s.
# Adversary: Start EXPLOIT_VULN dd3f096b-0055-49cf-8d8e-b15f367a4316 on host 25 at 2381.5s.
# Adversary: Processed EXPLOIT_VULN dd3f096b-0055-49cf-8d8e-b15f367a4316 on host 25 at 2383.9s.
# Adversary: Start EXPLOIT_VULN c1fd984f-c992-4f58-9216-550cbc0367be on host 25 at 2383.9s.
# Adversary: Processed EXPLOIT_VULN c1fd984f-c992-4f58-9216-550cbc0367be on host 25 at 2386.4s.
# Adversary: Start EXPLOIT_VULN c5a1e106-15f3-453b-842c-6baa74195f20 on host 25 at 2386.4s.
# Adversary: Processed EXPLOIT_VULN c5a1e106-15f3-453b-842c-6baa74195f20 on host 25 at 2392.5s.
# Adversary: Start EXPLOIT_VULN fe6e3794-f78f-408e-8944-3789866b36e3 on host 25 at 2392.5s.
# Adversary: Processed EXPLOIT_VULN fe6e3794-f78f-408e-8944-3789866b36e3 on host 25 at 2393.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 4f6fc500-72be-4451-938a-6356a178d568 on host 25 at 2393.3s.
# Adversary: Processed EXPLOIT_VULN 4f6fc500-72be-4451-938a-6356a178d568 on host 25 at 2394.4s.
# Adversary: Start EXPLOIT_VULN d0c47fce-4dab-4ec3-b4a9-a67b3dfb7363 on host 25 at 2394.4s.
# Adversary: Processed EXPLOIT_VULN d0c47fce-4dab-4ec3-b4a9-a67b3dfb7363 on host 25 at 2404.0s.
# Adversary: Start EXPLOIT_VULN 068d56b3-af53-4cbb-9b49-3313286b8257 on host 25 at 2404.0s.
# MTD: CompleteTopologyShuffle triggered 2404.1s
# MTD: CompleteTopologyShuffle deployed in the network at 2404.1s.
# Adversary: Processed EXPLOIT_VULN 068d56b3-af53-4cbb-9b49-3313286b8257 on host 25 at 2414.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2d05f641-9ffa-4f1d-80ba-44c178e0edcf on host 25 at 2414.2s.
# Adversary: Processed EXPLOIT_VULN 2d05f641-9ffa-4f1d-80ba-44c178e0edcf on host 25 at 2417.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 97d3372b-82f8-40a2-8e41-8e128a7bcd78 on host 25 at 2417.7s.
# Adversary: Processed EXPLOIT_VULN 97d3372b-82f8-40a2-8e41-8e128a7bcd78 on host 25 at 2422.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9681c118-5cdf-4277-8c69-4f08283db27f on host 25 at 2422.1s.
# Adversary: Processed EXPLOIT_VULN 9681c118-5cdf-4277-8c69-4f08283db27f on host 25 at 2425.2s.
# Adversary: Start EXPLOIT_VULN bb662643-b26d-4647-88be-5e95676840e7 on host 25 at 2425.2s.
# Adversary: Processed EXPLOIT_VULN bb662643-b26d-4647-88be-5e95676840e7 on host 25 at 2430.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 59c6d53d-1dc3-46e8-b28f-ef0da912e53d on host 25 at 2430.3s.
# Adversary: Processed EXPLOIT_VULN 59c6d53d-1dc3-46e8-b28f-ef0da912e53d on host 25 at 2432.5s.
# Adversary: Start EXPLOIT_VULN b5515c7d-f40c-412e-979b-b73f4d06ba79 on host 25 at 2432.5s.
# Adversary: Processed EXPLOIT_VULN b5515c7d-f40c-412e-979b-b73f4d06ba79 on host 25 at 2435.4s.
# Adversary: Start EXPLOIT_VULN d5452677-b0fb-4983-9672-1e0a42c0ef76 on host 25 at 2435.4s.
# Adversary: Processed EXPLOIT_VULN d5452677-b0fb-4983-9672-1e0a42c0ef76 on host 25 at 2446.4s.
# Adversary: Start EXPLOIT_VULN 3e8815cf-800c-4dd8-b63a-f9df6884eaa9 on host 25 at 2446.4s.
# Adversary: Processed EXPLOIT_VULN 3e8815cf-800c-4dd8-b63a-f9df6884eaa9 on host 25 at 2449.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bdbc2d46-741b-4f50-97b7-608626f24845 on host 25 at 2449.7s.
# Adversary: Processed EXPLOIT_VULN bdbc2d46-741b-4f50-97b7-608626f24845 on host 25 at 2451.0s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 18feb656-ea2c-48ce-a053-d1e5ad23283a on host 25 at 2451.0s.
# Adversary: Processed EXPLOIT_VULN 18feb656-ea2c-48ce-a053-d1e5ad23283a on host 25 at 2453.5s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 46f307fa-b841-4ff4-ac25-7adafadb526d on host 25 at 2453.5s.
# Adversary: Processed EXPLOIT_VULN 46f307fa-b841-4ff4-ac25-7adafadb526d on host 25 at 2458.1s.
# Adversary: Start EXPLOIT_VULN 1382c5f5-e050-4197-aa44-4ee59da12de2 on host 25 at 2458.1s.
# Adversary: Processed EXPLOIT_VULN 1382c5f5-e050-4197-aa44-4ee59da12de2 on host 25 at 2461.5s.
# Adversary: Start EXPLOIT_VULN 9f1f3f8f-3f0f-474b-8149-ee181c28be6a on host 25 at 2461.5s.
# Adversary: Processed EXPLOIT_VULN 9f1f3f8f-3f0f-474b-8149-ee181c28be6a on host 25 at 2464.3s.
# Adversary: Start EXPLOIT_VULN 4fda1180-6a3b-48d1-bc43-0f41df77dff9 on host 25 at 2464.3s.
# Adversary: Processed EXPLOIT_VULN 4fda1180-6a3b-48d1-bc43-0f41df77dff9 on host 25 at 2465.8s.
# Adversary: Start EXPLOIT_VULN 23e9f5c0-c359-4abe-b0fe-d08e673b3710 on host 25 at 2465.8s.
# Adversary: Processed EXPLOIT_VULN 23e9f5c0-c359-4abe-b0fe-d08e673b3710 on host 25 at 2468.5s.
# Adversary: Start EXPLOIT_VULN 0e3d86ea-4e07-443c-b73d-25f7ec493186 on host 25 at 2468.5s.
# Adversary: Processed EXPLOIT_VULN 0e3d86ea-4e07-443c-b73d-25f7ec493186 on host 25 at 2469.6s.
# Adversary: Start EXPLOIT_VULN c80dd649-0d52-45f4-9e83-8948d9e40780 on host 25 at 2469.6s.
# Adversary: Processed EXPLOIT_VULN c80dd649-0d52-45f4-9e83-8948d9e40780 on host 25 at 2477.9s.
# Adversary: Start EXPLOIT_VULN ce293928-17f3-42b8-8c62-af5544ac32ec on host 25 at 2477.9s.
# Adversary: Processed EXPLOIT_VULN ce293928-17f3-42b8-8c62-af5544ac32ec on host 25 at 2478.2s.
# Adversary: Start EXPLOIT_VULN 95114dba-1de7-4a25-974e-b0a2120c2239 on host 25 at 2478.2s.
# Adversary: Processed EXPLOIT_VULN 95114dba-1de7-4a25-974e-b0a2120c2239 on host 25 at 2481.4s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2d157bac-3405-45c6-a535-919366ae1b4b on host 25 at 2481.4s.
# Adversary: Processed EXPLOIT_VULN 2d157bac-3405-45c6-a535-919366ae1b4b on host 25 at 2491.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN cf4a9c9d-c35f-4dae-a32a-ca31e64fbbcc on host 25 at 2491.3s.
# Adversary: Processed EXPLOIT_VULN cf4a9c9d-c35f-4dae-a32a-ca31e64fbbcc on host 25 at 2499.7s.
# Adversary: Start EXPLOIT_VULN e4a8610f-e307-4f5d-bbfe-a8015221dc49 on host 25 at 2499.7s.
# Adversary: Processed EXPLOIT_VULN e4a8610f-e307-4f5d-bbfe-a8015221dc49 on host 25 at 2516.9s.
# Adversary: Start EXPLOIT_VULN 64a3a5dc-4a4b-406b-873d-ef85d7180dce on host 25 at 2516.9s.
# Adversary: Processed EXPLOIT_VULN 64a3a5dc-4a4b-406b-873d-ef85d7180dce on host 25 at 2522.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN af45c42b-f12b-4f89-a598-eee98c6ea2de on host 25 at 2522.6s.
# MTD: CompleteTopologyShuffle finished in 120.1s at 2524.2s.
# MTD: Interrupted EXPLOIT_VULN at 2524.2s!
# Adversary: Restarting with SCAN_HOST at 2544.6s!
# Adversary: Start SCAN_HOST at 2544.6s.
# Adversary: Processed SCAN_HOST at 2549.6s.
# Adversary: Start ENUM_HOST at 2549.6s.
# Adversary: Processed ENUM_HOST at 2554.6s.
# Adversary: Start SCAN_PORT at 2554.6s.
# Adversary: Processed SCAN_PORT at 2579.6s.
# Adversary: Start EXPLOIT_VULN 66805a9e-fdb9-4ef4-a674-ff7950d9ab25 on host 17 at 2579.6s.
# Adversary: Processed EXPLOIT_VULN 66805a9e-fdb9-4ef4-a674-ff7950d9ab25 on host 17 at 2580.1s.
# Adversary: Start EXPLOIT_VULN af033484-74e6-4b04-85d8-60d80e7b68c4 on host 17 at 2580.1s.
# Adversary: Processed EXPLOIT_VULN af033484-74e6-4b04-85d8-60d80e7b68c4 on host 17 at 2584.6s.
# Adversary: Start EXPLOIT_VULN 2039ce40-20d9-450b-a82b-9bec313df670 on host 17 at 2584.6s.
# Adversary: Processed EXPLOIT_VULN 2039ce40-20d9-450b-a82b-9bec313df670 on host 17 at 2591.1s.
# Adversary: Start EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 17 at 2591.1s.
# Adversary: Processed EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 17 at 2602.2s.
# Adversary: Start EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 17 at 2602.2s.
# MTD: OSDiversity triggered 2604.3s
# MTD: OSDiversity deployed in the network at 2604.3s.
# Adversary: Processed EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 17 at 2610.5s.
# Adversary: Start EXPLOIT_VULN 2a37429d-8ef0-48db-b452-883f137f0337 on host 17 at 2610.5s.
# Adversary: Processed EXPLOIT_VULN 2a37429d-8ef0-48db-b452-883f137f0337 on host 17 at 2623.0s.
# Adversary: Start EXPLOIT_VULN 5a71abde-fa5a-4777-8342-552bb03858dc on host 17 at 2623.0s.
# Adversary: Processed EXPLOIT_VULN 5a71abde-fa5a-4777-8342-552bb03858dc on host 17 at 2625.4s.
# Adversary: Start EXPLOIT_VULN 2f22b83e-8008-4f9e-b78d-60a2e495b386 on host 17 at 2625.4s.
# Adversary: Processed EXPLOIT_VULN 2f22b83e-8008-4f9e-b78d-60a2e495b386 on host 17 at 2633.1s.
# Adversary: Start EXPLOIT_VULN aa429b1c-b488-45d9-88b6-9d627c83fd1d on host 17 at 2633.1s.
# Adversary: Processed EXPLOIT_VULN aa429b1c-b488-45d9-88b6-9d627c83fd1d on host 17 at 2639.6s.
# Adversary: Start EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 17 at 2639.6s.
# Adversary: Processed EXPLOIT_VULN a20709fd-7220-412d-841e-2d9d938d2c6e on host 17 at 2660.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 14e08126-fdc2-49b7-8488-3e295c46a1d0 on host 17 at 2660.3s.
# Adversary: Processed EXPLOIT_VULN 14e08126-fdc2-49b7-8488-3e295c46a1d0 on host 17 at 2663.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 74fdbd2e-b7d3-40e2-8321-7bb9b6768442 on host 17 at 2663.9s.
# Adversary: Processed EXPLOIT_VULN 74fdbd2e-b7d3-40e2-8321-7bb9b6768442 on host 17 at 2665.1s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9aa8ee38-c61a-4dab-b916-35749b466cf4 on host 17 at 2665.1s.
# Adversary: Processed EXPLOIT_VULN 9aa8ee38-c61a-4dab-b916-35749b466cf4 on host 17 at 2671.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 9994eb53-f61e-4d41-b4be-66440a488bde on host 17 at 2671.2s.
# MTD: OSDiversity finished in 80.5s at 2684.9s.
# MTD: Interrupted EXPLOIT_VULN at 2684.9s!
# Adversary: Restarting with SCAN_PORT at 2705.1s!
# Adversary: Start SCAN_PORT at 2705.1s.
# Adversary: Processed SCAN_PORT at 2730.1s.
# Adversary: Start EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 17 at 2730.1s.
# Adversary: Processed EXPLOIT_VULN f5402eef-b579-426e-9126-f78831115ab9 on host 17 at 2741.0s.
# Adversary: Start EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 17 at 2741.0s.
# Adversary: Processed EXPLOIT_VULN 8e6e4dae-9cb3-49cd-9599-c92f95b01054 on host 17 at 2749.5s.
# Adversary: Start EXPLOIT_VULN 2a37429d-8ef0-48db-b452-883f137f0337 on host 17 at 2749.5s.
# Adversary: Processed EXPLOIT_VULN 2a37429d-8ef0-48db-b452-883f137f0337 on host 17 at 2761.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 5a71abde-fa5a-4777-8342-552bb03858dc on host 17 at 2761.9s.
# Adversary: Processed EXPLOIT_VULN 5a71abde-fa5a-4777-8342-552bb03858dc on host 17 at 2764.3s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 2f22b83e-8008-4f9e-b78d-60a2e495b386 on host 17 at 2764.3s.
# Adversary: Processed EXPLOIT_VULN 2f22b83e-8008-4f9e-b78d-60a2e495b386 on host 17 at 2772.8s.
# Adversary: Start EXPLOIT_VULN aa429b1c-b488-45d9-88b6-9d627c83fd1d on host 17 at 2772.8s.
# Adversary: Processed EXPLOIT_VULN aa429b1c-b488-45d9-88b6-9d627c83fd1d on host 17 at 2779.9s.
# Adversary: Start EXPLOIT_VULN 2039ce40-20d9-450b-a82b-9bec313df670 on host 17 at 2779.9s.
# Adversary: Processed EXPLOIT_VULN 2039ce40-20d9-450b-a82b-9bec313df670 on host 17 at 2786.2s.
# Adversary: Start EXPLOIT_VULN 9994eb53-f61e-4d41-b4be-66440a488bde on host 17 at 2786.2s.
# Adversary: Processed EXPLOIT_VULN 9994eb53-f61e-4d41-b4be-66440a488bde on host 17 at 2804.6s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 256c7fbd-7b04-4393-98a0-7c53262a6a67 on host 17 at 2804.6s.
# MTD: ServiceDiversity triggered 2805.0s
# MTD: ServiceDiversity deployed in the network at 2805.0s.
# Adversary: Processed EXPLOIT_VULN 256c7fbd-7b04-4393-98a0-7c53262a6a67 on host 17 at 2819.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bef69255-2bbb-4dce-84de-48d75b29bf10 on host 17 at 2819.9s.
# Adversary: Processed EXPLOIT_VULN bef69255-2bbb-4dce-84de-48d75b29bf10 on host 17 at 2825.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Host 17 has been compromised at 2825.8s!
# Adversary: Start SCAN_NEIGHBOR at 2825.8s.
# Adversary: Processed SCAN_NEIGHBOR at 2830.8s.
# Adversary: Start ENUM_HOST at 2830.8s.
# Adversary: Processed ENUM_HOST at 2835.8s.
# Adversary: Start ENUM_HOST at 2835.8s.
# Adversary: Processed ENUM_HOST at 2840.8s.
# Adversary: Start ENUM_HOST at 2840.8s.
# Adversary: Processed ENUM_HOST at 2845.8s.
# Adversary: Start ENUM_HOST at 2845.8s.
# Adversary: Processed ENUM_HOST at 2850.8s.
# Adversary: Start SCAN_PORT at 2850.8s.
# MTD: ServiceDiversity finished in 70.5s at 2875.5s.
# MTD: Interrupted SCAN_PORT at 2875.5s!
# Adversary: Restarting with SCAN_PORT at 2895.6s!
# Adversary: Start SCAN_PORT at 2895.6s.
# Adversary: Processed SCAN_PORT at 2920.6s.
# Adversary: Start EXPLOIT_VULN 9681c118-5cdf-4277-8c69-4f08283db27f on host 25 at 2920.6s.
# Adversary: Processed EXPLOIT_VULN 9681c118-5cdf-4277-8c69-4f08283db27f on host 25 at 2923.8s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d5452677-b0fb-4983-9672-1e0a42c0ef76 on host 25 at 2923.8s.
# Adversary: Processed EXPLOIT_VULN d5452677-b0fb-4983-9672-1e0a42c0ef76 on host 25 at 2932.6s.
# Adversary: Start EXPLOIT_VULN 6fe4c177-eabd-4ce4-84ce-eeaeaefa442d on host 25 at 2932.6s.
# Adversary: Processed EXPLOIT_VULN 6fe4c177-eabd-4ce4-84ce-eeaeaefa442d on host 25 at 2938.2s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN 1382c5f5-e050-4197-aa44-4ee59da12de2 on host 25 at 2938.2s.
# Adversary: Processed EXPLOIT_VULN 1382c5f5-e050-4197-aa44-4ee59da12de2 on host 25 at 2940.7s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN d5e32385-dbbf-4186-84f0-bc33a3e8abc0 on host 25 at 2940.7s.
# Adversary: Processed EXPLOIT_VULN d5e32385-dbbf-4186-84f0-bc33a3e8abc0 on host 25 at 2954.0s.
# Adversary: Start EXPLOIT_VULN d36d73da-76ff-459a-ac8f-2a6a7eda703b on host 25 at 2954.0s.
# Adversary: Processed EXPLOIT_VULN d36d73da-76ff-459a-ac8f-2a6a7eda703b on host 25 at 2957.9s.
# OS DEPENDENT VULNERABILITY EXPLOITED!
# Adversary: Start EXPLOIT_VULN bbdeb367-efd9-4665-aed6-4793afbd0778 on host 25 at 2957.9s.
# Adversary: Processed EXPLOIT_VULN bbdeb367-efd9-4665-aed6-4793afbd0778 on host 25 at 2966.9s.
# Adversary: Start EXPLOIT_VULN 1a0d0c34-5495-4bf4-aadf-e18252d0c185 on host 25 at 2966.9s.
# Adversary: Processed EXPLOIT_VULN 1a0d0c34-5495-4bf4-aadf-e18252d0c185 on host 25 at 2975.1s.
# Adversary: Start EXPLOIT_VULN dd3f096b-0055-49cf-8d8e-b15f367a4316 on host 25 at 2975.1s.
# Adversary: Processed EXPLOIT_VULN dd3f096b-0055-49cf-8d8e-b15f367a4316 on host 25 at 2977.4s.
# Adversary: Start EXPLOIT_VULN 80dd7d52-c12a-4db3-882d-f0286c863a09 on host 25 at 2977.4s.
# Adversary: Processed EXPLOIT_VULN 80dd7d52-c12a-4db3-882d-f0286c863a09 on host 25 at 2983.0s.
# Adversary: Start EXPLOIT_VULN 5a505d79-1b36-4d1e-bafb-3f83e938fa11 on host 25 at 2983.0s.
# Adversary: Processed EXPLOIT_VULN 5a505d79-1b36-4d1e-bafb-3f83e938fa11 on host 25 at 2987.6s.
# Adversary: Start EXPLOIT_VULN 86f8b810-792b-469e-900c-1e20e65a469f on host 25 at 2987.6s.
# Adversary: Processed EXPLOIT_VULN 86f8b810-792b-469e-900c-1e20e65a469f on host 25 at 2995.2s.
# Adversary: Start EXPLOIT_VULN b1bb2b4b-31ff-4ea6-a09f-a3719295387b on host 25 at 2995.2s.

# %%
evaluation.get_network().draw()
plt.show()

# %%
evaluation.visualise_mtd_operation()

# %%
evaluation.visualise_attack_operation_group_by_host()

# %%
evaluation.visualise_attack_operation()
# Out:
# total compromised hosts:  15

# %%
evaluation.compromise_record_by_attack_action()
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 8    EXPLOIT_VULN    63.078444    72.200282   9.121838             0
# 34   EXPLOIT_VULN   288.851656   294.233723   5.382068            13
# 74   EXPLOIT_VULN   636.265747   642.719167   6.453421             6
# 83   EXPLOIT_VULN   698.620898   702.144756   3.523858            18
# 120  EXPLOIT_VULN  1040.796905  1045.223176   4.426271             9
# 158  EXPLOIT_VULN  1261.427303  1264.289693   2.862391            23
# 170  EXPLOIT_VULN  1383.787226  1398.314597  14.527371            21
# 180  EXPLOIT_VULN  1468.286581  1488.936324  20.649743            11
# 188     SCAN_PORT  1552.750980  1577.750980  25.000000             5
# 197     SCAN_PORT  1617.750980  1642.750980  25.000000            24
# 205     SCAN_PORT  1703.186029  1728.186029  25.000000            28
# 215  EXPLOIT_VULN  1799.843918  1807.690236   7.846318            12
# 242  EXPLOIT_VULN  2061.581079  2071.310131   9.729051            22
# 262  EXPLOIT_VULN  2196.590908  2205.355502   8.764595             7
# 347  EXPLOIT_VULN  2819.855685  2825.844754   5.989069            17
#
#                         current_host_uuid compromise_host  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587               0
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec              13
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6               6
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7              18
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698               9
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34              23
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c              21
# 180  1c413663-0542-4ee9-b807-0bef4656aaff              11
# 188  ca9234f8-8134-4df2-b938-557d85816e55               5
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395              24
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f              28
# 215  59af67af-f26e-4829-beaf-e58136f81e61              12
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0              22
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1               7
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739              17
#
#                      compromise_host_uuid  current_host_attempt  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587                     1
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec                     2
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6                     2
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7                     1
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698                     1
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34                     1
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c                     1
# 180  1c413663-0542-4ee9-b807-0bef4656aaff                     2
# 188  ca9234f8-8134-4df2-b938-557d85816e55                     1
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395                     1
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f                     1
# 215  59af67af-f26e-4829-beaf-e58136f81e61                     2
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0                     1
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1                     1
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 8                      5                             0
# 34                    24                             1
# 74                    51                             2
# 83                    57                             3
# 120                   83                             4
# 158                  114                             5
# 170                  121                             6
# 180                  128                             7
# 188                  129                             8
# 197                  129                             9
# 205                  129                            10
# 215                  135                            11
# 242                  154                            12
# 262                  166                            13
# 347                  233                            14
#
#                                 compromise_users interrupted_in  \
# 8      [Bidget, Aurilia, Seline, Jermaine, Adah]           None
# 34           [Carmella, Chiarra, Prissie, Verna]           None
# 74         [Ellene, Max, Gilberte, Alie, Serena]           None
# 83   [Melonie, Lissi, Gianina, Quinn, Consolata]           None
# 120                  [Lori, Kaia, Casandra, Bev]           None
# 158             [Mair, Sherilyn, Nydia, Ariella]           None
# 170          [Christal, Christina, Talya, Timmy]           None
# 180          [Meagan, Krystalle, Freddi, Amelia]           None
# 188                  [Dulce, Kyla, Enid, Sherri]           None
# 197                         [Anna-Diane, Donica]           None
# 205                        [Kevyn, Kenna, Shela]           None
# 215                 [Anjanette, Silvana, Rozina]           None
# 242               [Gianna, Cheri, Kaycee, Karee]           None
# 262                      [Tandy, Judie, Stevana]           None
# 347                             [Joly, Antonina]           None
#
#     interrupted_by   color curr_host_token
# 8             None  yellow               1
# 34            None  yellow               2
# 74            None  yellow               4
# 83            None  yellow               6
# 120           None  yellow               8
# 158           None  yellow              10
# 170           None  yellow              11
# 180           None  yellow               7
# 188           None   green              13
# 197           None   green              14
# 205           None   green              15
# 215           None  yellow               9
# 242           None  yellow              16
# 262           None  yellow              17
# 347           None  yellow              20

# %%
evaluation.compromise_record_by_attack_action('SCAN_PORT')
# Out:
#           name   start_time  finish_time  duration  current_host  \
# 188  SCAN_PORT  1552.750980  1577.750980      25.0             5
# 197  SCAN_PORT  1617.750980  1642.750980      25.0            24
# 205  SCAN_PORT  1703.186029  1728.186029      25.0            28
#
#                         current_host_uuid compromise_host  \
# 188  ca9234f8-8134-4df2-b938-557d85816e55               5
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395              24
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f              28
#
#                      compromise_host_uuid  current_host_attempt  \
# 188  ca9234f8-8134-4df2-b938-557d85816e55                     1
# 197  67b19dfa-b93f-4f02-9320-d1bae8890395                     1
# 205  1ebd5d5d-a1b7-43c6-9993-58fe8a20ed9f                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 188                  129                             8
# 197                  129                             9
# 205                  129                            10
#
#                 compromise_users interrupted_in interrupted_by  color  \
# 188  [Dulce, Kyla, Enid, Sherri]           None           None  green
# 197         [Anna-Diane, Donica]           None           None  green
# 205        [Kevyn, Kenna, Shela]           None           None  green
#
#     curr_host_token
# 188              13
# 197              14
# 205              15

# %%
evaluation.compromise_record_by_attack_action('EXPLOIT_VULN')
# Out:
#              name   start_time  finish_time   duration  current_host  \
# 8    EXPLOIT_VULN    63.078444    72.200282   9.121838             0
# 34   EXPLOIT_VULN   288.851656   294.233723   5.382068            13
# 74   EXPLOIT_VULN   636.265747   642.719167   6.453421             6
# 83   EXPLOIT_VULN   698.620898   702.144756   3.523858            18
# 120  EXPLOIT_VULN  1040.796905  1045.223176   4.426271             9
# 158  EXPLOIT_VULN  1261.427303  1264.289693   2.862391            23
# 170  EXPLOIT_VULN  1383.787226  1398.314597  14.527371            21
# 180  EXPLOIT_VULN  1468.286581  1488.936324  20.649743            11
# 215  EXPLOIT_VULN  1799.843918  1807.690236   7.846318            12
# 242  EXPLOIT_VULN  2061.581079  2071.310131   9.729051            22
# 262  EXPLOIT_VULN  2196.590908  2205.355502   8.764595             7
# 347  EXPLOIT_VULN  2819.855685  2825.844754   5.989069            17
#
#                         current_host_uuid compromise_host  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587               0
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec              13
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6               6
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7              18
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698               9
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34              23
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c              21
# 180  1c413663-0542-4ee9-b807-0bef4656aaff              11
# 215  59af67af-f26e-4829-beaf-e58136f81e61              12
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0              22
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1               7
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739              17
#
#                      compromise_host_uuid  current_host_attempt  \
# 8    783747b6-3717-4d39-8cf6-2e70da982587                     1
# 34   f3cfc077-6841-40f5-a662-ab4ff5af7dec                     2
# 74   0f8b7105-f8b7-47a4-9dd4-c194f2678ac6                     2
# 83   c7bb0329-ad09-4132-8682-1989e52f68e7                     1
# 120  2cda3dd8-d971-481c-aea4-0fa36f908698                     1
# 158  ad47b5fe-5092-448d-ad91-d2c9fe6c8a34                     1
# 170  b50f14cc-7d8b-4f99-8c75-32e2867cdc5c                     1
# 180  1c413663-0542-4ee9-b807-0bef4656aaff                     2
# 215  59af67af-f26e-4829-beaf-e58136f81e61                     2
# 242  2c1251b3-ea99-43b9-a9fe-3a2238a02ba0                     1
# 262  2e920fcd-89d5-4be0-b0fe-aa869f4addf1                     1
# 347  f5ce5e57-3039-4b6e-a07e-aa5981797739                     1
#
#      cumulative_attempts  cumulative_compromised_hosts  \
# 8                      5                             0
# 34                    24                             1
# 74                    51                             2
# 83                    57                             3
# 120                   83                             4
# 158                  114                             5
# 170                  121                             6
# 180                  128                             7
# 215                  135                            11
# 242                  154                            12
# 262                  166                            13
# 347                  233                            14
#
#                                 compromise_users interrupted_in  \
# 8      [Bidget, Aurilia, Seline, Jermaine, Adah]           None
# 34           [Carmella, Chiarra, Prissie, Verna]           None
# 74         [Ellene, Max, Gilberte, Alie, Serena]           None
# 83   [Melonie, Lissi, Gianina, Quinn, Consolata]           None
# 120                  [Lori, Kaia, Casandra, Bev]           None
# 158             [Mair, Sherilyn, Nydia, Ariella]           None
# 170          [Christal, Christina, Talya, Timmy]           None
# 180          [Meagan, Krystalle, Freddi, Amelia]           None
# 215                 [Anjanette, Silvana, Rozina]           None
# 242               [Gianna, Cheri, Kaycee, Karee]           None
# 262                      [Tandy, Judie, Stevana]           None
# 347                             [Joly, Antonina]           None
#
#     interrupted_by   color curr_host_token
# 8             None  yellow               1
# 34            None  yellow               2
# 74            None  yellow               4
# 83            None  yellow               6
# 120           None  yellow               8
# 158           None  yellow              10
# 170           None  yellow              11
# 180           None  yellow               7
# 215           None  yellow               9
# 242           None  yellow              16
# 262           None  yellow              17
# 347           None  yellow              20

# %%
evaluation.compromise_record_by_attack_action('BRUTE_FORCE')
# Out:
# Empty DataFrame
# Columns: [name, start_time, finish_time, duration, current_host, current_host_uuid, compromise_host, compromise_host_uuid, current_host_attempt, cumulative_attempts, cumulative_compromised_hosts, compromise_users, interrupted_in, interrupted_by, color, curr_host_token]
# Index: []

# %%
evaluation.evaluation_result_by_compromise_checkpoint()
# Out:
# [{'time_to_compromise': 1292.1944692087566,
#   'attack_success_rate': 0.47619047619047616,
#   'host_compromise_ratio': 0.1,
#   'mtd_execution_frequency': 0.005216447423407677}]
